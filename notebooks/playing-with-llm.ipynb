# %% [markdown]
# ## Imports

# %%
import os
import sys
import json
import gc
import re
import json
from tqdm import notebook as tqdm
import pickle
import itertools
from collections import Counter, defaultdict

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import httpx
import logging

from llm_input import top_tokens_lvl0, top_tokens_lvl1, gpt_output_lvl0, gpt_output_lvl1

OLLAMA_CONFIG = {
    "keep_alive": "5m",
    "stream": False,
}

SEP_TOKEN = '<sep>'

gpt_output_lvl0 = np.array(list(gpt_output_lvl0.items()))
gpt_output_lvl1 = np.array(list(gpt_output_lvl1.items()))

# %%
sns.set(font_scale=1.2, palette='Set2')

plt.rcParams['font.family'] = 'DejaVu Serif'
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.markersize'] = 12
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams['legend.fontsize'] = 24
plt.rcParams['axes.titlesize'] = 30
plt.rcParams['axes.labelsize'] = 24
plt.rcParams["figure.figsize"] = (12, 7)

SEED = 123

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# Смотрим на распределение секций внутри текста.
#
# Секция -- всё, что обёрнуто в `==`
#
# Из примеров выше: `== Майндмап ==`, `== Аннотация ==`, `== Видео ==`
#
# Далее фильтруем по числу документов в секции: их должно быть не менее 20.
#
# В конце сортируем по числу документов в секции.

# %%
with open('../data/in/0x1tv-dataset.pickle', 'rb') as fd:
    data = pickle.load(fd)

# %% [markdown]
# Оставляем 3 домена: заголовок, аннотация и тезисы

# %%
def get_min_position(*positions):
    return min([pos for pos in positions if pos >= 0], default=len(data))

def extract_section_text(data, section_name):
    if section_name == 'Аннотация':
        blockquote_pattern = r'<blockquote>(.*?)</blockquote>'
        match = re.search(blockquote_pattern, data, re.DOTALL)
        return match.group(1).strip() if match else None
    
    section_pattern = fr'==\s*{re.escape(section_name)}\s*=='
    section_start = re.search(section_pattern, data)
    
    if not section_start:
        return None
   
    position = section_start.end()

    # Look for stop tokens and the start of next sections
    stop_tokens = ['{{----}}', '{{LinksSection}}', '== Примечания и отзывы ==']
    ends = [data.find(token, position) for token in stop_tokens]
    end_position = get_min_position(*ends)
    
    if end_position != len(data):
        return data[position:end_position].strip()
    
    return data[position:].strip()

def extract_sections(data):
    sections = ['Аннотация', 'Thesis', 'Тезисы', 'Расширенные тезисы']
    extracted_texts = {section: extract_section_text(data, section) for section in sections}
    return extracted_texts


def coalesce(dct, keys):
    for key in keys:
        if dct[key] is not None or len(dct[key]) > 0:
            return dct[key]
    return None


def parse_document(doc):
    parsed_doc = dict()
    parsed_doc['title'] = doc['title']
    
    sections_data = extract_sections(doc['text'])
    parsed_doc['annotation'] = sections_data['Аннотация']
    parsed_doc['thesis'] = coalesce(sections_data, ['Thesis', 'Тезисы', 'Расширенные тезисы'])
    
    return parsed_doc

# %% [markdown]
# Парсим ФИО докладчиков

# %%
def speaker_detect(text):
    speakers = re.findall(r'(?<={{Speaker\|).*(?=}})', text)
    preproc_speakers = []
    for speaker in speakers:
        preproc_speakers.extend(speaker.split('|'))
    return preproc_speakers


all_speakers = [speaker_detect(text['text']) for text in data['articles']]

print('Число докладов без спикеров:', len(list(filter(lambda x: len(x) == 0, all_speakers))))
print('Число докладов с одним спикером:', len(list(filter(lambda x: len(x) == 1, all_speakers))))
print('Число докладов с двумя спикерами:', len(list(filter(lambda x: len(x) == 2, all_speakers))))
print('Число докладов с не менее тремя спикерами:', len(list(filter(lambda x: len(x) >= 3, all_speakers))))
# Out:
# Число докладов без спикеров: 74
# Число докладов с одним спикером: 2313
# Число докладов с двумя спикерами: 119
# Число докладов с не менее тремя спикерами: 35

# %% [markdown]
# Фильтруем категории

# %%
def clear_categories(sample):
    return [re.sub('Категория:', '', el) for el in sample]


text_categories = [clear_categories(item['categories']) for item in data['articles']]
child_categories = [item['title'] for item in data['categories']]
parent_categories = [clear_categories(item['categories']) for item in data['categories']]

ALL_CATEGORIES = list(set(itertools.chain(*text_categories)) | set(child_categories) | set(itertools.chain(*parent_categories)))

child_to_parent_categories = {item['title']: clear_categories(item['categories']) for item in data['categories']}

# %%
ALL_CATEGORIES
# Out:
# ['Геймификация в UX',
#  'SECON-2017',
#  'Михаил Карпов',
#  'Никита Ермаков',
#  'Илья Богунов',
#  'Игорь Буренков',
#  'Александр Прозоров',
#  'Дмитрий Сатин',
#  'Олег Громов',
#  'Виталий Камянский',
#  'Евгений Кабанов',
#  'Юрий Орлов',
#  'Наталия Смирнова',
#  'Владимир Вахлов',
#  'Михаил Заборов',
#  'Наим Шафиев',
#  'UI бизнес-приложений',
#  'Оценка сотрудников',
#  'Виктория Придатко',
#  'Zuzi Sochova',
#  'Константин Рыбас',
#  'Екатерина Потапова',
#  'Дмитрий Подлужный',
#  'Федор Ляхов',
#  'Алексей Лесовский',
#  'Кристина Пивоварова',
#  'Платон Днепровский',
#  'Голосовой интерфейс',
#  'Никита Фролов',
#  'Александр Легалов',
#  'Анастасия Маркина',
#  'Дмитрий Петерсон',
#  'Сергей Егоров',
#  'Владислав Рябченко',
#  'Денис Доронин',
#  'User Story',
#  'Михаил Трутнев',
#  'Мотивация',
#  'САПР',
#  'Дмитрий Мартынов',
#  'Денис Петров',
#  'Артур Арсенов',
#  'Стас Павлов',
#  'OSEDUCONF-2019',
#  'Linux-дистрибутивы для Enterprise',
#  'Waterfall',
#  'Елена Сагалаева',
#  'Сергей Гельметдинов',
#  'Наталья Зиновьева',
#  'Инга Егорова',
#  'Илья Каштанкин',
#  'Павел Пыхтин',
#  'Виталий Лютиков',
#  'Marko Kazhich',
#  'Олег Кутырин',
#  'Сергей Котырев',
#  'OpenShift',
#  'Павел Гордейчук',
#  'Сергей Дмитриев™',
#  'Сергей Дмитриев',
#  'Agile-масштабирование',
#  'Яков Кириленко',
#  'Илья Пухальский',
#  'Андрей Шевченко',
#  'Алексей Какунин',
#  'Продуктовая аналитика',
#  'AgileKitchen (2013-10-18)',
#  'Legacy',
#  'Михаил Рубин',
#  'Гульфия Курмангалеева',
#  'Антон Иванов',
#  'Александр Числер',
#  'Максим Кузьмич',
#  'Андрей Сабынин',
#  'Алексей Рякин',
#  'Henrik Kniberg',
#  'Pivot',
#  'Виталий Трифанов',
#  'SECR-2015',
#  'Виктор Волонтей',
#  'Графовые базы данных',
#  'OSEDUCONF-2015',
#  'Татьяна Бибикова',
#  'Евгений Ткаченко',
#  'Тестирование',
#  'OSSDEVCONF-2015',
#  'Gerald Pfeifer',
#  'Naresh Jain',
#  'Татьяна Смехнова',
#  'Михаил Левин',
#  'Компьютерная графика',
#  'Юрий Яхно',
#  'Свободные лицензии',
#  'Дизайн',
#  'Андрей Шорин',
#  'Visual Studio',
#  'Сергей Котлов',
#  'Reduan Daniel Oon',
#  'Руслан Смелянский',
#  'Санжар Кеттебеков',
#  'Светлана Ратнер',
#  'Процесс разработки',
#  'Илья Евлампиев',
#  'Константин Гурнов',
#  'SECR',
#  'Илья Лейрих',
#  'Сергей Карбовский',
#  'Сергей Асрян',
#  'Виктор Черногоров',
#  'Дмитрий Платонов',
#  'NeedContacts',
#  'Бизнес и СПО',
#  'Сергей Платов',
#  'Статический анализ кода',
#  'Алексей Радецкий',
#  'Антон Зотин',
#  'Mickey Mantle',
#  'LeanKanbanRussia-2014',
#  'Open-source PAAS',
#  'Оксана Некрасова',
#  'Александр Чистяков',
#  'Юзабилити в играх',
#  'Доклады на иностранных языках',
#  'Александр Сухинин',
#  'OSSDEVCONF-2016',
#  'Михаил Шигорин',
#  'Глеб Кудрявцев',
#  'Константин Бредюк',
#  'Юзабилити интернет-магазинов',
#  'Константин Трушкин',
#  'Data Analysis',
#  'Бизнес в IT',
#  'Роман Россов',
#  'Андрей Бордунов',
#  'Илья Бовкунов',
#  'Александр Козуб',
#  'Виктор Стрелков',
#  'Марина Климова',
#  'Scott Sullivan',
#  'Владимир Рябчиков',
#  'Сергей Грушко',
#  'Александра Кононова',
#  'MySQL',
#  'Денис Доротенко',
#  'Павел Удалов',
#  'ProfsoUX-2013',
#  'Jenkins',
#  'Александр Горный',
#  'Алексей Костарев',
#  'Clsync',
#  'ProductMeetup',
#  'Михаил Кулаков',
#  'Рина Ужевко',
#  'Картография',
#  'Сергей Мартыненко',
#  'Евгений Новиков',
#  'ToPublish',
#  'Александр Орлов',
#  'Максим Гапонов',
#  'Влад Головач',
#  'Юзабилити исследования',
#  'Денис Макошенко',
#  'Ольга Олейник',
#  'Дмитрий Снисарь',
#  'Игорь Шаталкин',
#  'Елена Емелина',
#  'Владимир Горовой',
#  'Алексей Ерпелев',
#  'Илья Бизин',
#  'Сергей Туленцев',
#  'Roman Dimenko',
#  'Системы управления версиями',
#  'Владимир Селезнев',
#  'Антон Павлов',
#  'Борис Славин',
#  'Сети',
#  'Александр Половцев',
#  'Евгений Зинин',
#  'Антон Зуев',
#  'Андрей Пономаренко',
#  'Robert Farish',
#  'Алексей Цветков',
#  'Сергей Андржеевский',
#  'Александр Фролов',
#  'Иван Анисимов',
#  'Антон Хабурский',
#  'Константин Беляев',
#  'Вадим Цесько',
#  'Евгений Бурмако',
#  'Анатолий Левенчук',
#  'Владимир Атаманов',
#  'ProfsoUX-2018',
#  'Денис Яковлев',
#  'Тимофей Лавренюк',
#  'Антон Хританков',
#  'Юзабилити',
#  'Shannon Ewan',
#  'Доклады на украинском',
#  'Алексей Каленюк',
#  'Максим Высоких',
#  'Machine Learning',
#  'Евгений Курышев',
#  'Дмитрий Сподарец',
#  '.NET',
#  'Дмитрий Кандалов',
#  'HelloConf MTS-2019',
#  'Сергей Гриднев',
#  'Виталий Герко',
#  'Дмитрий Никонов',
#  'Максим Мазин',
#  'Александр Неведовский',
#  'Олег Воронов',
#  'Сергей Исаев',
#  'Фаина Хает',
#  'Татьяна Елисеева',
#  'Иван Бакаидов',
#  'Николай Рыжиков',
#  'Сергей Пилкин',
#  'Владимир Алексеев',
#  'Виктор Короневич',
#  'Анастасия Шишова',
#  'Игорь Дёмин',
#  'Дмитрий Кирьянов',
#  'Анастасия Мусина',
#  'Георгий Грибков',
#  'SECR-2012',
#  'Иван Филиппов',
#  'Александр Клюкач',
#  'Информационная безопасность',
#  'Кумир',
#  'Александр Байкин',
#  'Яков Сироткин',
#  'SECR-2016',
#  'Диана Вайнберг',
#  'Виктор Яковлев™',
#  'Михаил Высоковский',
#  'Теория ограничений',
#  'Андрей Романюк',
#  'Павел Грозян',
#  'Николай Потехин',
#  'Яна Чирко',
#  'Хранение данных',
#  'LSM',
#  'Дмитрий Дзюба',
#  'Анатолий Тыкушин',
#  'Орхан Гасымов',
#  'Александр Яковлев™',
#  'Рауф Еникеев',
#  'Юлия Муфель',
#  'Marcio Leibovitch',
#  'Кирилл Чувилин',
#  'Extreme Programming',
#  'Антон Литвиненко',
#  'PingWinFest-2012',
#  'Максим Цепков',
#  'Роман Хатько',
#  'Анатолий Хомоненко',
#  'Семен Молотков',
#  'Алексей Евменков',
#  'Иван Лосик',
#  'Павел Андрианов',
#  'Петр Евстифеев',
#  'Ирина Скурская',
#  'Илья Рыженков',
#  'Александр Кривенцов',
#  'Open-source and hardware',
#  'Екатерина Черняева',
#  'DevOps',
#  'Евгений Алексеев',
#  'Лиза Семяновская',
#  'Родион Кертлинг',
#  'Дмитрий Думик',
#  'Родион Нагорнов',
#  'Юрий Михайлуц',
#  'Владимир Суховерхий',
#  'Сергей Гулько',
#  'Облачные сервисы',
#  'Александр Ненашев',
#  'Анна Лопатухина',
#  'Сергей Карлов',
#  'Антон Сметанин',
#  'Андрей Заходяйченко',
#  'Илья Кантор',
#  'Анна Галахова',
#  'Денис Степанов',
#  'Сергей Кудряшов',
#  'Всеволод Родионов',
#  'Линейки конференций',
#  'Андрей Пономарев',
#  'Психология пользователя',
#  'Константин Пархоц',
#  'ROSS-2013',
#  'Психология разработки',
#  'Алексей Дьяченко',
#  'SECR-2017',
#  'ADD-2010',
#  'Доверенная загрузка',
#  'Екатерина Храмкова',
#  'Екатерина Рудина',
#  'Виталий Медведев',
#  'Business rules engine',
#  'Максим Мозговой',
#  'Карьера в IT',
#  'NotThemed',
#  'Константин Пермяков',
#  'Евгений Говако',
#  'Сергей Суханов',
#  'Государство и софт',
#  'Erlang',
#  'Reviewed',
#  'Свободные библиотеки построения графиков',
#  'Александр Андрюхин',
#  'Михаил Маркушевич',
#  'LVEE-2014',
#  'Анна Мельничук',
#  'Александр Рябинин',
#  'Александр Барановский',
#  'Денис Ефремов',
#  'Иван Ильин',
#  'Безопасность',
#  'Андрей Волков',
#  'Разработка операционных систем',
#  'Ирина Виноградова',
#  'Максим Фролов',
#  'Никита Манько',
#  'Виктор Филиппов',
#  'Яна Кузьмина',
#  'Павел Музыка',
#  'Ираклий Агладзе',
#  'Екатерина Умнова',
#  'Pascale Xelot-Dugat',
#  'Игорь Хапов',
#  'Викентий Лапа',
#  'Екатерина Макаренко',
#  'Алексей Колоколов',
#  'Владимир Рубанов',
#  'Найти контакты',
#  'Алексей Копылов',
#  'Игорь Одинцов',
#  'Илья Матвейчиков',
#  'Миля Райко',
#  'Елизавета Ревзина',
#  'Илья Захаров™',
#  'Bluemix',
#  'Arduino',
#  'Анастасия Кугач',
#  'Андрей Себрант',
#  'Иван Кульков',
#  'Александр Календарев',
#  'Денис Шамгин',
#  'Дмитрий Павлов',
#  'Александр Безбородов',
#  'Леонид Kaнтер',
#  'Олеся Воронович',
#  'Jeff Patton',
#  '1C',
#  'Григорий Кондаков',
#  'Дмитрий Яковлев',
#  'Петр Степанов',
#  'Информационные системы ВУЗов',
#  'Николай Пасынков',
#  'Вадим Коротынский',
#  'Кирилл Мокевнин',
#  'Александр Уланов',
#  'Степан Зинин',
#  'Андрей Степенко',
#  'Алексей Надененко',
#  'Сергей Бронников',
#  'Антон Катков',
#  'Андрей Непрель',
#  'Оксана Сергеева',
#  'Организационный анализ',
#  'Евгения Сотина',
#  'Филипп Дельгядо',
#  'Антон Уймин',
#  'Антонина Рябуша',
#  'Кирилл Коринский',
#  'Ольга Киселева',
#  'Сергей Васильев',
#  'Виталий Воронович',
#  'Health',
#  'Документирование',
#  'Александр Бурт',
#  'Илья Кузнецов',
#  'Алексей Солнцев',
#  'Слава Панкратов',
#  'Денис Дубров',
#  'Сервис-ориентированная архитектура',
#  'Malik Mangier',
#  'RISC-V',
#  'Наташа Мантл',
#  'Артем Зырянов',
#  'Tатьяна Васильева',
#  'Mechanics',
#  'Владимир Колесников',
#  'Владислав Кудинов',
#  'Елена Мандрикова',
#  'Сергей Маковеев',
#  'Lua',
#  'Денис Хачко',
#  'Андрей Сикорский',
#  'Тестирование производительности',
#  'Евгений Овчаренко',
#  'Маргарита Титова',
#  'Александр Андреев',
#  'Дмитрий Репин',
#  'Олег Андрианов',
#  'Zabbix',
#  'Александр Доманицкий',
#  'Agile — технологические практики',
#  'AgileDays-2011',
#  'Глеб Фотенгауэр-Малиновский',
#  'Дмитрий Холопов',
#  'SVM',
#  'Запуск продукта',
#  'Kubernetes',
#  'Сергей Герасимов',
#  'Технологии будущего',
#  'Сергей Щербинин',
#  'Сергей Карпеш',
#  'Николай Кутеев',
#  'Kanban',
#  'Альберт Сорокин',
#  'Java EE',
#  'Технологии',
#  'Руслан Саввотин',
#  'AR',
#  'Арсений Мешков',
#  'Ксения Рогальская',
#  'Андрей Смирнов',
#  'Дмитрий Державин',
#  'Михаил Фролов',
#  'Дмитрий Романов',
#  'Ретроспектива',
#  'Александр Шалимов',
#  'Олег Якубенков',
#  'Николай Волынкин',
#  'Игорь Агамирзян',
#  'Евгений Мироничев',
#  'Константин Кривцов',
#  'Максим Лейкин',
#  'Сергей Морозов',
#  'Алёна Кирдина',
#  'Ольга Ткаченко',
#  'Василий Толстой',
#  'Разработка десктоп-приложений',
#  'Юлия Михайлова',
#  'Виктор Сычев',
#  'Алексей Сорокин',
#  'Егор Гилёв',
#  'Дарья Федотова',
#  'Евгений Шишкин',
#  'Taucraft',
#  'Александр Епифанов',
#  'Олег Дырдин',
#  'Вячеслав Нестеров',
#  'Алексей Васильев',
#  'Даниил Батурин',
#  'Михаил Кулёмин',
#  'Михаил Малышев',
#  'OSEDUCONF-2018',
#  'Юрий Василевский',
#  'Linux',
#  'Николай Ефанов',
#  'Linux-дистрибутивы',
#  'AgileDays-2015',
#  'Евгений Цветухин',
#  'Сергей Ярец',
#  'Тестирование UI',
#  'Глеб Сологуб',
#  'Дамир Тенишев',
#  'Геймификация',
#  'Павел Богданов',
#  'Ruby',
#  'Евгений Петров',
#  'Наталья Руколь',
#  'Фреймворки',
#  'Обучение проектному менеджменту',
#  'Ренат Зарипов',
#  'Дмитрий Ясевич',
#  'Константин Семенов',
#  'Александр Турханов',
#  'Дмитрий Цителов',
#  'Борис Вольфсон',
#  'Иван Перл',
#  'Владислав Чистяков',
#  'Андрей Малашенко',
#  'Валентин Анопренко',
#  'Hardware',
#  'Илья Трегубов',
#  'Алексей Кривицкий',
#  'Виталий Шульга',
#  'OSSDEVCONF-2019',
#  'Павел Шишкин',
#  'Константин Макарычев',
#  'Елена Беляева',
#  'Валентина Третьякова',
#  'Михаил Кузнецов',
#  'Дмитрий Дубограев',
#  'Веб-разработка',
#  'Николай Ясинский',
#  'Leo Maas',
#  'Дмитрий Лайер',
#  'Алена Лысякова',
#  'Андрей Маркелов',
#  'ProfsoUX-2017',
#  'Олег Звонов',
#  'Олег Гарипов',
#  'Валентин Малых',
#  'Сергей Прохоренко',
#  'Дмитрий Башакин',
#  'Григорий Сенин',
#  'Евгений Пышкин',
#  'Базы данных',
#  'Object Oriented Programming',
#  'Clemence Lebrun',
#  'Дария Потеряхина',
#  'Роман Алёшкин',
#  'Владислав Иванишин',
#  'Антон Новиков',
#  'Исследовательское тестирование',
#  'Пётр Демин',
#  'Евгений Плужников',
#  'Лев Чернышов',
#  'Support',
#  'Максим Гвоздев',
#  'Программирование',
#  'Алексей Хорошилов',
#  'Ксения Петрова',
#  'Дмитрий Тарахно',
#  'Анализ программ и систем',
#  'Татьяна Колупаева',
#  'George Sharkov',
#  'Виталий Король',
#  'СПО в науке',
#  'Анна Хотимская',
#  'Дмитрий Терёхин',
#  'Александр Харкевич',
#  'Александр Бурцев',
#  'Алексей Горбунов',
#  'Николай Марков',
#  'Илья Бузюк',
#  'Scala',
#  'Выход на зарубежные рынки',
#  'Евгений Зиндер',
#  'Александр Гришкин',
#  'Андрей Садовых',
#  'Андрей Михеев',
#  'Groovy',
#  'Иван Панченко',
#  'Михаил Ганчиков',
#  'Николай Гребнев',
#  'Антон Черников',
#  'SPMConf-2011',
#  'Ксения Лобатая',
#  'Вадим Мустяца',
#  'Операционные системы',
#  'Ирина Гришанова',
#  'Олег Ненашев',
#  'Ansible',
#  'Надежда Тарасюк',
#  'Сергей Лагуткин',
#  'Михаил Зайцев',
#  'Светлана Яворская',
#  'Милан Прохаска',
#  'Michael Wong',
#  'Динамический анализ',
#  'Дмитрий Щитинин',
#  'Владимир Литошенко',
#  'Тренды Open-source',
#  'Алексей Бакушин',
#  'Collaboration tools',
#  'Open-source CRM',
#  'Илья Никляев',
#  'Алексей Косарчук',
#  'Доклад со стенограммой',
#  'Олег Аксенов',
#  'Сергей Сурганов',
#  'Владимир Оглоблин',
#  'Видеосвязь',
#  'Ирина Дудина',
#  'СУБД',
#  'Цолак Гукасян',
#  'Ирина Снегова',
#  'Наталья Горелиц',
#  'Кирилл Кравцов',
#  'CRIU',
#  'Процесс тестирования',
#  'Ирина Плешкова',
#  'LAMP',
#  'Вадим Шишкин',
#  'Виктор Кузьмин',
#  'Всеволод Котляров',
#  'Софья Чебанова',
#  'ProfsoUX-2016',
#  'ProfsoUX-2015',
#  'Тимур Усатый',
#  'Аният Курбанова',
#  'Кирилл Степанов',
#  'Алексей Синцов',
#  'Александр Сербул',
#  'Игорь Клейнер',
#  'WUD-2011',
#  'Максим Богуславский',
#  'NUI',
#  'OSSDEVCONF-2017',
#  'Артем Кузнецов',
#  'Денис Рысцов',
#  'Matt Schuetze',
#  'Кирилл Климов',
#  'Евгений Одновал',
#  'Елена Махно',
#  'Роман Черных',
#  'СПО в Госуправлении',
#  'Go',
#  'Антон Фадеев',
#  'Тарас Бризицкий',
#  'Александр Наталенко',
#  'Лёля Гурашвили',
#  'Ксения Макарова',
#  'Никита Филиппов',
#  'Айк Асланян',
#  'Кирилл Лебедев',
#  'Марина Соболевская',
#  'Маусымжан Нурмагамбетова',
#  'Никита Лазарев',
#  'Константин Кичинский',
#  'Наталья Рябочкина',
#  'Татьяна Бунто',
#  'Василий Чепцов',
#  'Евгений Служаев',
#  'Ирина Максимова',
#  'Дмитрий Сатанин',
#  'Алексей Пустыгин',
#  'Андраш Густи',
#  'Павел Новиков',
#  'Юрий Гугнин',
#  'Аутентификация и авторизация',
#  'Игорь Марков',
#  'Валентин Макаров',
#  'Эксплуатация',
#  'Алексей Петров®',
#  'Александр Лесневский',
#  'Алексей Лесных',
#  'Александр Баранов',
#  'Юрий Загорулько',
#  'Павел Кошак',
#  'Дмитрий Бугайченко',
#  'Илья Чернецкий',
#  'AWS',
#  'Hegle Sarapuu',
#  'Евгений Кулаков',
#  'Сергей Павельчук',
#  'AstraLinux',
#  'Елена Журавлева',
#  'Александр Калугин',
#  'Евгений Анастасиев',
#  'OSEDUCONF',
#  'Сергей Старолетов',
#  'RTOS',
#  'Юрий Андреев',
#  'Леонид Мигунов',
#  'ROSS-2014',
#  'Сергей Лунёв',
#  'Никита Абраменко',
#  'Алексей Копытов',
#  'Федор Кондратович',
#  'Владимир Климонтович',
#  'Егор Миронь',
#  'Андрей Бреслав',
#  'Виталий Сороко',
#  'Csharp',
#  'Дмитрий Шаматрин',
#  'Вера Карпова',
#  'Тойохиро Канаяма',
#  'Антон Толкунов',
#  'Сергей Голубев',
#  'Виталий Обернихин',
#  'Nick Void',
#  'Артем Тихомиров',
#  'Donald Reinertsen',
#  'Дмитрий Соловьев',
#  'Антон Мидюков',
#  'Kevin Richardson',
#  'Станислав Сартасов',
#  'Continuous Integration',
#  'Совещания',
#  'ZFS',
#  'Илона Саркисова',
#  'MIPS',
#  'Игорь Куликов',
#  'Сергей Золотарёв',
#  'Олег Волков',
#  'Борис Седов',
#  'Adrian Reed',
#  'Инструменты майнтейнеров',
#  'Автоматизированное тестирование',
#  'Алексей Баранцев',
#  'Евгений Филиппов',
#  'Александр Самонов',
#  'Михаил Завилейский',
#  'Михаил Мамонов',
#  'Алексей Зиновьев',
#  'Анатолий Рубцов',
#  'Микаэл Гелецян',
#  'CouchDB',
#  'Павел Воронов',
#  'Екатерина Лаврищева',
#  'Growth Hacking',
#  'Максим Буковский',
#  'Робототехника',
#  'Константин Осипов',
#  'Дмитрий Туфанов',
#  'Сергей Максимов',
#  'Кирилл Терехов',
#  'Роман Каплун',
#  'People Management',
#  'Ольга Аминова',
#  'Планирование в Agile',
#  'Dave Snowden',
#  'Николай Марин',
#  'Арег Мелик-Адамян',
#  'Анатолий Якушин',
#  'Наум Фейгенсон',
#  'Nick van der Linde',
#  'ProductCampMinsk-2018',
#  'Юлия Урасова',
#  'Алексей Фёдоров',
#  'Евгений Виноградов',
#  'Дискуссии',
#  'Надежда Евстифеева',
#  'IT-образование',
#  'Святлана Ермаковіч',
#  'Сергей Булатицкий',
#  'Илхом Назаров',
#  'Андрей Селедкин',
#  'Виталий Балашов',
#  'Константин Шевцов',
#  'Дмитрий Иртегов',
#  'Саша Куценко',
#  'Сергей Канищев',
#  'Андрей Шадура',
#  'Иван Семерник',
#  'Олег Щеголев',
#  'Татьяна Авлочинская',
#  'Игорь Постаногов',
#  'Krzysztof Opasiak',
#  'Эльбрус',
#  'Open-source',
#  'Алексей Колотников',
#  'Федор Краснов',
#  'Сергей Парамонов',
#  'Евгения Фирсова',
#  'Алексей Бабахин',
#  'Наталья Тумашева',
#  'Анастасия Щеброва',
#  'Управление заинтересованными сторонами',
#  'Paul Epping',
#  'Петр Кондауров',
#  'LVEE-2017',
#  'Анатолий Заболотный',
#  'Максим Усиченко',
#  'Shaoying Liu',
#  'NLP',
#  'Надежда Минчева',
#  'Windows',
#  'Дмитрий Устюжанин',
#  'Михаил Ройтберг',
#  'OSDN-UA-2012',
#  'TDD',
#  'Тестирование мобильных приложений',
#  'Инга Юрьева',
#  'Лоренс Райт',
#  'Роман Юферев',
#  'Антон Уткин',
#  'Владимир Ли',
#  'Юрий Сойко',
#  'Анатолий Шалыто',
#  'Оксана Цветкова',
#  'Игорь Чижевский',
#  'Сергей Македонский',
#  'Владимир Иванов',
#  'Разработка игр',
#  'Иван Кровяков',
#  'Алексей Флоринский',
#  'Николай Пунтиков',
#  'Дмитрий Макаров',
#  'Дмитрий Шишигин',
#  'Анастасия Корнилова',
#  'Павел Белоусов',
#  'OSSDEVCONF-2018',
#  'Роман Савоченко',
#  'Роман Абрамов',
#  'Мария Пичугина',
#  'Юрий Первин',
#  'Дмитрий Петрашев',
#  'Евгений Годов',
#  'Алексей Ермаков',
#  'Илья Александров',
#  'Алексей Котов',
#  'Евгения Василенко',
#  'Андрей Коновалов',
#  'Звиад Кардава',
#  'Сергей Бессонов',
#  'Владимир Красильщик',
#  'Agile-культура',
#  'Елена Столбова',
#  'UX',
#  'Олег Клинчаев',
#  'SAP',
#  'Андрей Бабанин',
#  'Михаил Плискин',
#  'FreeIPA',
#  'Дмитрий Волошин',
#  'Accessibility',
#  'Роман Ставцев',
#  'Эмма Даниелян',
#  'Андрей Совцов',
#  'OSEDUCONF-2016',
#  'Сергей Нужненко',
#  'Василий Литвинов',
#  'Юлия Нечаева',
#  'Мобильная разработка',
#  'Сергей Белов',
#  'Виталий Липатов',
#  'Александр Кондратьев',
#  'Александр Лебедев',
#  'Алексей Пикулев',
#  'Андрей Майоров',
#  'Matthew Mosesohn',
#  'Алексей Чумаков',
#  'Бизнес-анализ',
#  'Андрей Григорьев',
#  'Михаил Ершов',
#  'Кирилл Шатилов',
#  'Luis Olsina',
#  'Дмитрий Лазаренко',
#  'Михаил Плаксин',
#  'Дмитрий Баландин',
#  'Владимир Фофана',
#  'Михаил Клементьев',
#  'Андрей Миронов',
#  'Андрей Волков™',
#  'Алгоритмы',
#  'Егор Кулагин',
#  'Информационная безопасность и СПО',
#  'Денис Пынькин',
#  'Александр Дымо',
#  'Давид Бадалян',
#  'Дженнифер Трелевич',
#  'Антон Белоусов',
#  'Михаил Вайсман',
#  'Linux-обучение',
#  'Gustav Wall',
#  'Андрей Димитров',
#  'Сергей Шершаков',
#  'Павел Жуков',
#  'Алексей Алексеев',
#  'Евгений Тян',
#  'Виталий Козловский',
#  'Алексей Шабалин',
#  'Максим Колпаков',
#  'Михаил Жарчев',
#  'PostgreSQL',
#  'Технологии крупных вендоров',
#  'Сергей Корольков',
#  'Георгий Савельев',
#  'Эдгар Казиахмедов',
#  'Госсектор',
#  'Михаил Румянцев',
#  'Редкие языки программирования',
#  'Cevat Balek',
#  'Татьяна Максимова',
#  'Управление требованиями',
#  'Светлана Савельева',
#  'Кроссплатформенная разработка',
#  'Николай Слёзкинский',
#  'Татьяна Пичхадзе',
#  'Анастасия Коханова',
#  'Олег Царев',
#  'Александр Тормасов',
#  'Константин Данилов',
#  'Сергей Авдошин',
#  'Философия программирования',
#  'Ольга Миронова',
#  'Вадим Реуцкий',
#  'Сергей Евтушенко',
#  'ALT Linux',
#  'Павел Бойко',
#  'Никита Коваль',
#  'Александр Демидов',
#  'Евгений Кобзев',
#  'Тагир Яппаров',
#  'Виктория Пилипцевич',
#  'Никита Гундобин',
#  'Алексей Гореминский',
#  'Сергей Будяков',
#  'Андрей Власовских',
#  'Евгений Потапов',
#  'Александр Ворон',
#  'Никита Ковригин',
#  'IP-телефония',
#  'Стас Фомин',
#  'Вадим Подольный',
#  'Альберт Янов',
#  'AgileDays-2013',
#  'Марат Абасалиев',
#  'Анастасия Ащеулова',
#  'Андрей Змушко',
#  'Леонид Нетребский',
#  'Олег Штейнберг',
#  'Леонид Блохин',
#  'Юлия Шарова',
#  'Александр Кириллов',
#  'Виталий Фридман',
#  'Руслан Шевченко',
#  'Процесс разработки UX и UI',
#  'Доклады на белорусском языке',
#  'Александр Козачок',
#  'Сергей Ковалев',
#  'ROSALab',
#  'Андрей Терехов',
#  'Андрей Конопля',
#  'Ксения Стернина',
#  'Анна Рид',
#  'Валерий Лаптев',
#  'Василий Моисеев',
#  'LVEE-2018',
#  'Feature Branches',
#  'Open-source и законы',
#  'Евгения Петрова',
#  'Валерий Егоров',
#  'Андрей Черепанов',
#  'Сергей Михайлов',
#  'TAU-платформа',
#  'Андрей Сапожников',
#  'Роман Иовлев',
#  'Распределенные системы',
#  'ProductCamp-2013',
#  'Антон Марченко',
#  'Яков Зайдельман',
#  'Василий Михайлов',
#  'Юзабилити в 1C',
#  'UXPeople-2015',
#  'Виталий Минко',
#  'B2B продукты',
#  'DSL-языки',
#  'Юрий Куприянов',
#  'Управление техподдержкой',
#  'OSDAY-2018',
#  'Андрей Мухаметов',
#  'Андрей Дмитриев',
#  'Андрей Неволин',
#  'Александр Щербаков',
#  'Николай Мациевский',
#  'Николай Соколовский',
#  'Екатерина Тупчик',
#  'Mkimage-profiles',
#  'Моделирование бизнес-процессов',
#  'Дмитрий Орлов',
#  'Riak',
#  'Петр Грибанов',
#  'Игорь Ботвиньев',
#  'Анна Мелехова',
#  'Илья Алешков',
#  'Никита Грошин',
#  'Эдуард Тибет',
#  'Иван Потапов',
#  'Вячеслав Москаленко',
#  'Николай Шилов',
#  'Марат Хабибуллин',
#  'Сергей Амелькин',
#  'Реклама компании',
#  'Александр Атцик',
#  'Надежда Свирновская',
#  'Фриланс',
#  'Андрей Ребров',
#  'Валентин Оносовский',
#  'Татьяна Зинченко',
#  'Kamil Grabowski',
#  'Вячеслав Стародумов',
#  'Георгий Дюльдин',
#  'Геннадий Драгун',
#  'Андрей Ненахов',
#  'Антон Овчинников™',
#  'Dino Esposito',
#  'Влад Лялин',
#  'Данил Механошин',
#  'Виртуальный ассистент',
#  'Сергей Колпаков',
#  'Александр Клыга',
#  'Артем Ломакин',
#  'Байрам Аннаков',
#  'PAAS',
#  'Blockchain',
#  'Евгений Кошкин',
#  'Алексей Лаевский',
#  'Владимир Железняк',
#  'Даниил Березун',
#  'Алексей Гапонов',
#  ...]

# %% [markdown]
# Удалим вручную все имена из списка категорий + `HasSpeaker`

# %% [markdown]
# 🧔: Ох, вручную ничего делать нельзя, невоспроизводимо и немодифицируемо. Да и вручную не выйдет («Pascale Xelot-Dugat» — это спикер)

# %%
ALL_CATEGORIES_WITHOUT_NAMES = set([
    '.NET',
    '1C',
    'ALT Linux',
    'ALTLinux на Эльбрусе',
    'AR',
    'AWS',
    'Accessibility',
    'Agile',
    'Agile Introduction',
    'Agile process',
    'Agile в корпорациях',
    'Agile — технологические практики',
    'Agile&Lean Mindset',
    'Agile-культура',
    'Agile-масштабирование',
    'Agile-преобразования',
    'Alfresco',
    'Ansible',
    'Arduino',
    'AstraLinux',
    'Atlassian',
    'Azure',
    'B2B продукты',
    'BDD',
    'BigData',
    'Blockchain',
    'Bluemix',
    'Business rules engine',
    'C++',
    'CMMI',
    'CQRS',
    'CRIU',
    'Clouds',
    'Clsync',
    'Code Review',
    'Collaboration tools',
    'Configuration Management',
    'ContactOK',
    'Continuous Integration',
    'CouchDB',
    'Csharp',
    'CustisWikiToLib',
    'Customer Journey Map',
    'DDD',
    'DSL-языки',
    'Data Analysis',
    'Deployment',
    'Design Thinking',
    'DevOps',
    'Draft',
    'E-commerce',
    'Embox',
    'Erlang',
    'Extreme Programming',
    'Feature Branches',
    'Firefox',
    'Foresight management',
    'FreeIPA',
    'Front end development',
    'Fsharp',
    'GWT',
    'Glibc',
    'Go',
    'Groovy',
    'Growth Hacking',
    'HR',
    'Hardware',
    'Health',
    'High Performace Computing',
    'Highload-архитектуры',
    'IP-телефония',
    'IT-законы',
    'IT-образование',
    'Impact Map',
    'Information Security',
    'Internet of Thing',
    'Java',
    'Java EE',
    'Javascript',
    'Jenkins',
    'Kanban',
    'Knowledge Management',
    'Kotlin',
    'Kubernetes',
    'LAMP',
    'LSM',
    'LeSS',
    'Lean',
    'Lean Startup',
    'Legacy',
    'Libreoffice',
    'Linux',
    'Linux для Эльбруса',
    'Linux-дистрибутивы',
    'Linux-дистрибутивы для Enterprise',
    'Linux-обучение',
    'Lua',
    'MIPS',
    'Machine Learning',
    'Mechanics',
    'Microsoft',
    'Misc',
    'Mkimage-profiles',
    'MongoDB',
    'Morpheus',
    'MySQL',
    'NLP',
    'NOSQL',
    'NUI',
    'Natural Language Processing',
    'NeedContacts',
    'Nemerle',
    'Node.js',
    'Object Oriented Programming',
    'Open-source',
    'Open-source CAD',
    'Open-source CMS',
    'Open-source CRM',
    'Open-source ERP',
    'Open-source PAAS',
    'Open-source TCO',
    'Open-source and Community',
    'Open-source and hardware',
    'Open-source communications',
    'Open-source for Enterprise',
    'Open-source operating systems',
    'Open-source projects',
    'Open-source СУБД',
    'Open-source и законы',
    'OpenShift',
    'OpenStack',
    'OpenVZ',
    'PAAS',
    'PHP',
    'Pascale Xelot-Dugat',
    'People Management',
    'Pivot',
    'PostgreSQL',
    'ProductMeetup',
    'Python',
    'RISC-V',
    'ROSA Linux',
    'ROSALab',
    'RTOS',
    'Reviewed',
    'Riak',
    'Ruby',
    'RunaWFE',
    'SAP',
    'SELinux',
    'SOLID',
    'SVM',
    'Samba',
    'Scala',
    'Scrum',
    'Serverless',
    'Sharepoint',
    'SkillsWiki',
    'Skype',
    'Software Defined Networks',
    'Strace',
    'Support',
    'TAU-платформа',
    'TDD',
    'Talks in English',
    'Tarantool',
    'Taucraft',
    'Team Communication',
    'Teмы',
    'ToPublish',
    'Tuukka Ahoniemi',
    'UI',
    'UI SmartTV',
    'UI бизнес-приложений',
    'UX',
    'UX + Agile',
    'UX проектирование',
    'User Story',
    'VCS',
    'Visual Studio',
    'Waterfall',
    'WebRTC',
    'Windows',
    'World Usability Day',
    'ZFS',
    'Zabbix',
    'Автоматизированное тестирование',
    'Алгоритмы',
    'Анализ программ и систем',
    'Аналитика',
    'Архитектура',
    'Архитектура информационных систем',
    'Архитектура серверных приложений',
    'Аутентификация и авторизация',
    'БПЛА',
    'Базы данных',
    'Байкал',
    'Безопасность',
    'Бизнес в IT',
    'Бизнес и СПО',
    'Бизнес-анализ',
    'Блиц-доклады',
    'Веб-дизайн',
    'Веб-разработка',
    'Вебинары PingWin',
    'Верификация',
    'Видеосвязь',
    'Визуализация',
    'Виртуализация',
    'Виртуальный ассистент',
    'Встраиваемые системы',
    'Выход на зарубежные рынки',
    'Геймификация',
    'Геймификация в UX',
    'Геолокация',
    'Голосовой интерфейс',
    'Госсектор',
    'Государство и софт',
    'Графовые базы данных',
    'Диаграммы Кано',
    'Дизайн',
    'Динамический анализ',
    'Дискуссии',
    'Дискуссии о юзабилити',
    'Доверенная загрузка',
    'Доклад со стенограммой',
    'Докладчики',
    'Доклады на английском',
    'Доклады на белорусском языке',
    'Доклады на иностранных языках',
    'Доклады на украинском',
    'Документация и Agile',
    'Документирование',
    'Запуск продукта',
    'Запуск продукта в Retail',
    'Инструменты майнтейнера',
    'Инструменты майнтейнеров',
    'Инструменты разработки',
    'Информационная безопасность',
    'Информационная безопасность и СПО',
    'Информационные системы ВУЗов',
    'Использование open-source',
    'Исследовательское тестирование',
    'История из практики',
    'Картография',
    'Карьера в IT',
    'Командообразование',
    'Компиляторы',
    'Компиляция под Linux',
    'Компьютерная графика',
    'Компьютерное зрение',
    'Конференции',
    'Корпоративные решения',
    'Криптография',
    'Кроссплатформенная разработка',
    'Круглый стол',
    'Кумир',
    'Лидерство',
    'Линейки конференций',
    'Локализация',
    'Маркетинг',
    'Мастер-классы',
    'Менеджмент',
    'Метрики качества',
    'Микропрограммирование',
    'Микросервисы',
    'Мобильная разработка',
    'Моделирование бизнес-процессов',
    'Моделирование физических систем',
    'Монетизация',
    'Мониторинг',
    'Мотивация',
    'Наука',
    'Облачные сервисы',
    'Образование',
    'Обучение',
    'Обучение бизнес-анализу',
    'Обучение бизнес-процессам',
    'Обучение проектному менеджменту',
    'Обучение системному программированию',
    'Онлайн-обучение',
    'Операционные системы',
    'Оптимизация приложения',
    'Опыт внедрения СПО',
    'Организационные изменения',
    'Организационный анализ',
    'Открытые данные',
    'Отладка',
    'Оценка сотрудников',
    'Очереди',
    'Параллельное программирование',
    'Пиктомир',
    'Планирование',
    'Планирование в Agile',
    'Планировка задач',
    'Привественные речи',
    'Программирование',
    'Программная архитектура',
    'Продуктовая аналитика',
    'Прототипирование UI',
    'Процесс разработки',
    'Процесс разработки UX и UI',
    'Процесс тестирования',
    'Психология пользователя',
    'Психология разработки',
    'Разработка open-source',
    'Разработка десктоп-приложений',
    'Разработка десктопных приложений под Windows',
    'Разработка игр',
    'Разработка операционных систем',
    'Распределенные системы',
    'Редкие языки программирования',
    'Реклама',
    'Реклама компании',
    'Рекомендательные системы',
    'Ретроспектива',
    'Рефакторинг',
    'Робототехника',
    'С++',
    'САПР',
    'СПО в Госуправлении',
    'СПО в России',
    'СПО в науке',
    'СПО в образовании',
    'СПО в творчестве',
    'СПО для системного администрирования',
    'СУБД',
    'Свободные библиотеки построения графиков',
    'Свободные лицензии',
    'Сервис-ориентированная архитектура',
    'Сети',
    'Системное администрирование',
    'Системное мышление',
    'Системный анализ',
    'Системный подход',
    'Системы управления версиями',
    'Скрытые категории',
    'Собрания ALT.NET',
    'Совещания',
    'Стажировка',
    'Статический анализ кода',
    'Стратегическое планирование',
    'ТРИЗ',
    'Темы',
    'Теория ограничений',
    'Тестирование',
    'Тестирование UI',
    'Тестирование игр',
    'Тестирование мобильных приложений',
    'Тестирование производительности',
    'Технологии',
    'Технологии будущего',
    'Технологии крупных вендоров',
    'Тренды Open-source',
    'Умные вещи',
    'Управление заинтересованными сторонами',
    'Управление качеством',
    'Управление продуктами',
    'Управление рисками',
    'Управление собой',
    'Управление техподдержкой',
    'Управление требованиями',
    'Файловые системы',
    'Философия программирования',
    'Философия юзабилити',
    'Финансовые системы',
    'Фреймворки',
    'Фриланс',
    'Функциональное программирование',
    'Хранение данных',
    'Хэши',
    'Эксплуатация',
    'Эльбрус',
    'Юзабилити',
    'Юзабилити в 1C',
    'Юзабилити в играх',
    'Юзабилити интернет-магазинов',
    'Юзабилити исследования',
    'Юзабилити мобильных устройств',
    'Юзабилити образование',
    'Юзабилити поиска',
    'Юзабилити текста',
    'Языки программирования',
])

# %%
child_to_parent_categories
# Out:
# {'.NET': ['Программирование'],
#  '1C': [],
#  'ADD-2010': ['Application Developers Days', 'Конференции'],
#  'ADD-2011': ['Application Developers Days', 'Конференции'],
#  'ADD-2012': ['Application Developers Days', 'Конференции'],
#  'ALTLinux на Эльбрусе': ['ALT Linux', 'Linux для Эльбруса'],
#  'ALT Linux': ['Linux-дистрибутивы для Enterprise'],
#  'AR': ['Программирование'],
#  'AWS': ['PAAS', 'Облачные сервисы'],
#  'Accessibility': ['Юзабилити'],
#  'Adrian Reed': ['Докладчики'],
#  'Agile': ['Менеджмент'],
#  'Agile&Lean Mindset': ['Agile-культура'],
#  'Agile-культура': ['Agile'],
#  'Agile-масштабирование': ['Agile'],
#  'Agile-преобразования': [],
#  'AgileDays': ['AgileDays-2011', 'AgileDays-2014', 'Линейки конференций'],
#  'AgileDays-2011': ['AgileDays', 'Конференции'],
#  'AgileDays-2013': ['AgileDays', 'Конференции'],
#  'AgileDays-2014': ['AgileDays', 'Конференции'],
#  'AgileDays-2015': ['AgileDays', 'Конференции'],
#  'AgileKitchen (2013-10-18)': ['AgileDays', 'Конференции'],
#  'Agile Introduction': ['Agile'],
#  'Agile process': ['Agile'],
#  'Agile в корпорациях': [],
#  'Agile — технологические практики': ['Agile'],
#  'Ahmed Sidky': ['Докладчики'],
#  'Ales Zivkovic': ['Докладчики'],
#  'Alfresco': ['Open-source projects'],
#  'AnalystDays-2012': ['Конференции'],
#  'Andrew Zusman': ['Докладчики'],
#  'Andrzej Pietrasiewicz': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Ansible': ['DevOps'],
#  'Application Developers Days': ['ADD-2010', 'Линейки конференций'],
#  'Arduino': ['Open-source and hardware'],
#  'AstraLinux': ['Linux-дистрибутивы'],
#  'Atlassian': [],
#  'Azure': ['PAAS', 'Облачные сервисы'],
#  'B2B продукты': ['Управление продуктами'],
#  'BDD': ['Agile — технологические практики',
#   'Автоматизированное тестирование'],
#  'Bertrand Meyer': ['Докладчики'],
#  'BigData': [],
#  'Blockchain': ['Распределенные системы'],
#  'Bluemix': ['PAAS'],
#  'Bob Dorf': ['Докладчики'],
#  'Brian Pagán': ['Докладчики'],
#  'Business rules engine': ['Моделирование бизнес-процессов',
#   'Программирование'],
#  'C++': ['Программирование'],
#  'CMMI': ['Управление качеством'],
#  'CQRS': ['Программная архитектура'],
#  'CRIU': ['OpenVZ', 'Виртуализация'],
#  'Cevat Balek': ['Докладчики'],
#  'Clemence Lebrun': ['Докладчики'],
#  'Clouds': ['Системное администрирование'],
#  'Clsync': ['Open-source projects'],
#  'Code Review': ['Agile — технологические практики', 'Программирование'],
#  'Collaboration tools': ['Менеджмент'],
#  'Configuration Management': ['DevOps'],
#  'ContactOK': [],
#  'Continuous Integration': ['Тестирование'],
#  'CouchDB': ['Базы данных'],
#  'Crystal Valentine': ['Докладчики'],
#  'Csharp': [],
#  'Customer Journey Map': ['Управление продуктами', 'Юзабилити'],
#  'DDD': ['Бизнес-анализ', 'Программная архитектура'],
#  'DSL-языки': ['Программирование'],
#  'Data Analysis': ['Наука'],
#  'Dave Snowden': ['Докладчики'],
#  'David Anderson': ['Докладчики'],
#  'David Garlan': ['Докладчики'],
#  'David Goldsmith': ['Докладчики'],
#  'David West': ['Докладчики'],
#  'Denis Dorval': ['Докладчики'],
#  'Deployment': ['Программирование', 'Системное администрирование'],
#  'Design Thinking': ['Дизайн', 'Управление продуктами'],
#  'DevOps': ['Agile — технологические практики', 'Системное администрирование'],
#  'Dino Esposito': ['Докладчики'],
#  'Donald Reinertsen': ['Докладчики'],
#  'Draft': [],
#  'E-commerce': ['Программирование'],
#  'Embox': ['Open-source operating systems', 'RTOS'],
#  'Eric Reiss': ['Докладчики'],
#  'Erlang': ['Программирование'],
#  'Eugeniy Fedirets': ['Докладчики'],
#  'Extreme Programming': ['Agile — технологические практики',
#   'Программирование'],
#  'Felix GV': ['Докладчики'],
#  'Firefox': ['Open-source projects'],
#  'Foresight management': ['Стратегическое планирование'],
#  'Franck Descollonges': ['Докладчики'],
#  'FreeIPA': ['Open-source projects', 'Аутентификация и авторизация'],
#  'Front end development': ['Программирование'],
#  'Fsharp': ['Функциональное программирование'],
#  'GWT': ['Java', 'Веб-дизайн'],
#  'George Sharkov': ['Докладчики'],
#  'Gerald Pfeifer': ['Докладчики'],
#  'Glibc': ['Open-source projects'],
#  'Go': ['Программирование'],
#  'Gojko Adzic': ['Докладчики'],
#  'Groovy': ['Программирование'],
#  'Growth Hacking': ['Управление продуктами'],
#  'Gustav Wall': ['Докладчики'],
#  'HR': ['People Management'],
#  'Hardware': ['Программирование'],
#  'HasSpeaker': ['Скрытые категории'],
#  'Health': ['Misc'],
#  'Hegle Sarapuu': ['Докладчики'],
#  'HelloConf MTS-2019': ['Конференции'],
#  'Henrik Kniberg': ['Докладчики'],
#  'Hester Bruikman-Pagán': ['Докладчики'],
#  'High Performace Computing': ['Параллельное программирование'],
#  'Highload-архитектуры': ['Программирование'],
#  'Hyacinthe Briand': ['Докладчики'],
#  'IP-телефония': ['Программирование'],
#  'ISPRASOPEN-2018': ['Конференции'],
#  'IT-законы': ['Бизнес в IT'],
#  'IT-образование': ['Образование'],
#  'Impact Map': [],
#  'Information Security': ['Информационная безопасность'],
#  'Internet of Thing': ['Программирование'],
#  'Ivar Jacobson': ['Докладчики'],
#  'Java': ['Программирование'],
#  'Java EE': ['Java'],
#  'Javascript': ['Программирование'],
#  'Jeff Patton': ['Докладчики'],
#  'Jenkins': ['Continuous Integration', 'DevOps'],
#  'Jonathan Hansen': ['Докладчики'],
#  'Jurgis Ostasius': ['Докладчики'],
#  'Kamil Grabowski': ['Докладчики'],
#  'Kanban': ['Agile'],
#  'Kevin Richardson': ['Докладчики'],
#  'Knowledge Management': ['Менеджмент'],
#  'Kotlin': ['Программирование'],
#  'Krzysztof Opasiak': ['Докладчики'],
#  'Krzysztof Raś': ['Докладчики'],
#  'Kubernetes': ['DevOps', 'Open-source PAAS'],
#  'LAMP': ['Программирование'],
#  'LSM': ['Linux', 'Информационная безопасность'],
#  'LVEE-2014': ['Linux Vacation Eastern Europe', 'Конференции'],
#  'LVEE-2015': ['Linux Vacation Eastern Europe', 'Конференции'],
#  'LVEE-2017': ['Linux Vacation Eastern Europe', 'Конференции'],
#  'LVEE-2018': ['Linux Vacation Eastern Europe', 'Конференции'],
#  'LVEE-2019': ['Linux Vacation Eastern Europe', 'Конференции'],
#  'Lars Bendix': ['Докладчики'],
#  'LeSS': ['Agile-масштабирование'],
#  'Lean': ['Agile'],
#  'LeanKanbanRussia-2014': ['Конференции'],
#  'Lean Startup': ['Agile', 'Lean', 'Управление продуктами'],
#  'Legacy': [],
#  'Leo Maas': ['Докладчики'],
#  'Libreoffice': ['Open-source projects'],
#  'Linux': ['Open-source projects', 'Операционные системы'],
#  'Linux-дистрибутивы': ['Linux', 'Использование open-source'],
#  'Linux-дистрибутивы для Enterprise': ['Linux-дистрибутивы', 'Бизнес и СПО'],
#  'Linux-обучение': ['Linux', 'Образование'],
#  'Linux Vacation Eastern Europe': ['LVEE-2015', 'Линейки конференций'],
#  'Linux для Эльбруса': ['Linux-дистрибутивы', 'Эльбрус'],
#  'Lua': ['Языки программирования'],
#  'Luis Olsina': ['Докладчики'],
#  'Lutz Schmitt': ['Докладчики', 'Страницы с неработающими файловыми ссылками'],
#  'MIPS': ['Hardware'],
#  'Machine Learning': ['Алгоритмы'],
#  'Malik Mangier': ['Докладчики'],
#  'Marcio Leibovitch': ['Докладчики'],
#  'Mark Standeaven': ['Докладчики'],
#  'Marko Kazhich': ['Докладчики'],
#  'Matt Schuetze': ['Докладчики'],
#  'Matthew Mosesohn': ['Докладчики'],
#  'Mechanics': ['Наука'],
#  'Megan Donahue': ['Докладчики'],
#  'Michael Wong': ['Докладчики'],
#  'Michele Marchesi': ['Докладчики'],
#  'Mickey Mantle': ['Докладчики'],
#  'Microsoft': [],
#  'Misc': [],
#  'Mkimage-profiles': ['ALT Linux'],
#  'MongoDB': ['Open-source СУБД', 'Базы данных'],
#  'Morpheus': ['Natural Language Processing', 'Open-source projects'],
#  'MySQL': ['Open-source СУБД', 'Базы данных'],
#  'NLP': [],
#  'NOSQL': ['Базы данных'],
#  'NUI': ['UI'],
#  'Naresh Jain': ['Докладчики'],
#  'Natural Language Processing': ['Алгоритмы', 'Наука'],
#  'NeedContacts': [],
#  'Nemerle': ['Редкие языки программирования'],
#  'Nick Void': ['Докладчики'],
#  'Nick van der Linde': ['Докладчики'],
#  'NoYoutubeVideo': ['Скрытые категории'],
#  'Node.js': ['Программирование'],
#  'NotThemed': [],
#  'OSDAY-2018': ['Конференции'],
#  'OSDN-UA': ['Линейки конференций'],
#  'OSDN-UA-2012': ['OSDN-UA', 'Конференции'],
#  'OSDN-UA-2013': ['OSDN-UA', 'Конференции'],
#  'OSEDUCONF': ['OSEDUCONF-2013', 'OSEDUCONF-2014', 'Линейки конференций'],
#  'OSEDUCONF-2013': ['OSEDUCONF', 'Конференции'],
#  'OSEDUCONF-2014': ['OSEDUCONF', 'Конференции'],
#  'OSEDUCONF-2015': ['OSEDUCONF', 'Конференции'],
#  'OSEDUCONF-2016': ['OSEDUCONF', 'Конференции'],
#  'OSEDUCONF-2017': ['OSEDUCONF'],
#  'OSEDUCONF-2018': ['OSEDUCONF'],
#  'OSEDUCONF-2019': ['OSEDUCONF', 'Конференции'],
#  'OSSDEVCONF': ['OSSDEVCONF-2014', 'OSSDEVCONF-2017', 'Линейки конференций'],
#  'OSSDEVCONF-2013': ['OSSDEVCONF', 'Конференции'],
#  'OSSDEVCONF-2014': ['OSSDEVCONF', 'Конференции'],
#  'OSSDEVCONF-2015': ['OSSDEVCONF', 'Конференции'],
#  'OSSDEVCONF-2016': ['OSSDEVCONF', 'Конференции'],
#  'OSSDEVCONF-2017': ['OSSDEVCONF', 'Конференции'],
#  'OSSDEVCONF-2018': ['OSSDEVCONF', 'Конференции'],
#  'OSSDEVCONF-2019': ['OSSDEVCONF', 'Конференции'],
#  'Object Oriented Programming': ['Программирование'],
#  'Open-source': ['Темы'],
#  'Open-source CAD': ['Open-source projects'],
#  'Open-source CMS': ['Open-source projects'],
#  'Open-source CRM': ['Open-source projects'],
#  'Open-source ERP': ['Open-source projects'],
#  'Open-source PAAS': ['Open-source projects', 'PAAS'],
#  'Open-source TCO': ['Open-source', 'Бизнес и СПО'],
#  'Open-source and Community': ['Open-source'],
#  'Open-source and hardware': ['Hardware',
#   'Open-source projects',
#   'Использование open-source'],
#  'Open-source communications': ['Open-source projects'],
#  'Open-source for Enterprise': ['Использование open-source'],
#  'Open-source operating systems': ['Open-source projects'],
#  'Open-source projects': ['Open-source'],
#  'Open-source СУБД': ['Open-source projects'],
#  'Open-source и законы': ['IT-законы', 'Open-source'],
#  'OpenShift': ['DevOps', 'Open-source PAAS'],
#  'OpenStack': ['Open-source projects'],
#  'OpenVZ': ['Linux', 'Open-source projects', 'Виртуализация'],
#  'PAAS': ['Программирование'],
#  'PHP': ['LAMP'],
#  'Pascale Xelot-Dugat': ['ContactOK', 'Докладчики'],
#  'Paul Epping': ['Докладчики'],
#  'Paul Turner': ['Докладчики'],
#  'People Management': ['Менеджмент'],
#  'Peter Morville': ['Докладчики'],
#  'PingWinFest-2012': ['Конференции'],
#  'Pivot': ['Управление продуктами'],
#  'PostgreSQL': ['Open-source projects', 'Базы данных'],
#  'ProductCamp-2013': ['ProductCampRussia', 'Конференции'],
#  'ProductCampMinsk-2014': ['ProductCampRussia', 'Конференции'],
#  'ProductCampMinsk-2018': ['ProductCampRussia', 'Конференции'],
#  'ProductCampRussia': ['ProductCamp-2013',
#   'ProductCampSpb-2015',
#   'Линейки конференций'],
#  'ProductCampSPB-2012': ['ProductCampRussia', 'Конференции'],
#  'ProductCampSpb-2015': ['ProductCampRussia', 'Конференции'],
#  'ProductCampSpb-2017': ['ProductCampRussia', 'Конференции'],
#  'ProductMeetup': [],
#  'ProfsoUX': ['ProfsoUX-2015', 'ProfsoUX-2018'],
#  'ProfsoUX-2013': ['ProfsoUX', 'Конференции'],
#  'ProfsoUX-2014': ['ProfsoUX', 'Конференции'],
#  'ProfsoUX-2015': ['ProfsoUX', 'Конференции'],
#  'ProfsoUX-2016': ['ProfsoUX', 'Конференции'],
#  'ProfsoUX-2017': ['ProfsoUX', 'Конференции'],
#  'ProfsoUX-2018': ['ProfsoUX', 'Конференции'],
#  'ProfsoUX-2019': ['ProfsoUX', 'Конференции'],
#  'Python': [],
#  'RISC-V': ['Hardware', 'Open-source and hardware'],
#  'ROSALab': [],
#  'ROSA Linux': ['Linux-дистрибутивы'],
#  'ROSS-2013': ['Конференции'],
#  'ROSS-2014': ['Конференции'],
#  'RTOS': ['Операционные системы', 'Разработка операционных систем'],
#  'Reduan Daniel Oon': ['Докладчики'],
#  'Reviewed': [],
#  'Riak': ['Программирование'],
#  'Richard Soley': ['Докладчики'],
#  'Robert Farish': ['Докладчики'],
#  'Roman Dimenko': ['ContactOK', 'Докладчики'],
#  'Ruby': ['Программирование'],
#  'RunaWFE': ['Business rules engine', 'Open-source projects'],
#  'SAP': ['Технологии крупных вендоров'],
#  'SECON-2017': ['Конференции'],
#  'SECR': ['Линейки конференций'],
#  'SECR-2012': ['SECR', 'Конференции'],
#  'SECR-2013': ['SECR', 'Конференции'],
#  'SECR-2014': ['SECR', 'Конференции'],
#  'SECR-2015': ['SECR', 'Конференции'],
#  'SECR-2016': ['SECR', 'Конференции'],
#  'SECR-2017': ['SECR', 'Конференции'],
#  'SECR-2018': ['SECR', 'Конференции'],
#  'SECR-2019': ['SECR', 'Конференции'],
#  'SELinux': ['Информационная безопасность и СПО'],
#  'SOLID': ['Программная архитектура'],
#  'SPMConf-2011': ['Конференции'],
#  'SQADays-11': ['Конференции'],
#  'Samba': ['Open-source projects'],
#  'Sandra Aleksieje': ['ContactOK', 'Докладчики'],
#  'Scala': ['Программирование'],
#  'Scott Sullivan': ['ContactOK', 'Докладчики'],
#  'Scrum': ['Agile', 'Менеджмент'],
#  'Sebastiano Armeli': ['Докладчики'],
#  'Serverless': ['Архитектура серверных приложений'],
#  'Shannon Ewan': ['Докладчики'],
#  'Shaoying Liu': ['Докладчики'],
#  'Sharepoint': ['Программирование'],
#  'SkillsWiki': ['Конференции'],
#  'Skype': [],
#  'Slava Muchnick': ['Докладчики'],
#  'Slavy Slavov': ['Докладчики'],
#  'Software Defined Networks': ['Виртуализация', 'Системное администрирование'],
#  'Stefan Koehler': ['Докладчики'],
#  'Stephan Goericke': ['Докладчики'],
#  'Strace': ['Linux',
#   'Open-source projects',
#   'Динамический анализ',
#   'Мониторинг'],
#  'Suleman Shahid': ['Докладчики'],
#  'Support': ['Процесс разработки', 'Управление продуктами'],
#  'TAU-платформа': ['Open-source projects', 'Ruby', 'Мобильная разработка'],
#  'TDD': ['Agile — технологические практики',
#   'Автоматизированное тестирование'],
#  'Talks in English': [],
#  'Tarantool': ['Open-source СУБД'],
#  'Taucraft': [],
#  'Team Communication': ['Менеджмент'],
#  'Teмы': [],
#  'ToPublish': ['Скрытые категории'],
#  'Tuukka Ahoniemi': ['Докладчики'],
#  'Tатьяна Васильева': ['Докладчики'],
#  'UI': ['Юзабилити'],
#  'UI SmartTV': ['UI'],
#  'UI бизнес-приложений': ['Юзабилити'],
#  'UX': ['Юзабилити'],
#  'UXPeople-2013': ['Конференции'],
#  'UXPeople-2015': ['Конференции'],
#  'UXRussia-2011': ['Конференции'],
#  'UX + Agile': ['Agile', 'Процесс разработки UX и UI'],
#  'UX проектирование': ['Юзабилити'],
#  'User Story': ['Управление требованиями'],
#  'VCS': ['Программирование'],
#  'Visual Studio': ['Программирование'],
#  'Vladimir Pavlov': ['Докладчики'],
#  'WUD-2011': ['World Usability Day', 'Конференции'],
#  'WUD-2012': ['World Usability Day', 'Конференции'],
#  'Waterfall': ['Менеджмент'],
#  'WebRTC': ['Видеосвязь'],
#  'Wil van der Aalst': ['Докладчики'],
#  'Windows': ['Операционные системы'],
#  'World Usability Day': ['Линейки конференций'],
#  'Yaron Tsubery': ['Докладчики'],
#  'ZFS': ['Open-source projects', 'Файловые системы'],
#  'Zabbix': ['Open-source projects'],
#  'Zuzi Sochova': ['Докладчики'],
#  'Автоматизированное тестирование': ['Тестирование'],
#  'Азат Гайнутдинов': ['Докладчики'],
#  'Айк Асланян': ['Докладчики', 'Страницы с неработающими файловыми ссылками'],
#  'Айрат Садыков': ['Докладчики'],
#  'Алгоритмы': ['Программирование'],
#  'Алек Козлов': ['Докладчики'],
#  'Александр Андреев': ['Докладчики'],
#  'Александр Андронов': ['Докладчики'],
#  'Александр Андрюхин': ['ContactOK', 'Докладчики'],
#  'Александр Атцик': ['Докладчики'],
#  'Александр Бабкин': ['Докладчики'],
#  'Александр Байкин': ['Докладчики'],
#  'Александр Баранов': ['Докладчики'],
#  'Александр Барановский': ['Докладчики'],
#  'Александр Башарин': ['Докладчики'],
#  'Александр Безбородов': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Александр Белоусов': ['Докладчики'],
#  'Александр Боковой': ['Докладчики'],
#  'Александр Болдырев': ['ContactOK', 'Докладчики'],
#  'Александр Бородин': ['Докладчики'],
#  'Александр Бурт': ['Докладчики'],
#  'Александр Бурцев': ['Докладчики'],
#  'Александр Бындю': ['Докладчики'],
#  'Александр Ворон': ['Докладчики'],
#  'Александр Гаврилов': ['Докладчики'],
#  'Александр Галкин': ['Докладчики'],
#  'Александр Горник': ['Докладчики'],
#  'Александр Горный': ['Докладчики'],
#  'Александр Гришкин': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Александр Демидов': ['Докладчики'],
#  'Александр Долгарев': ['Докладчики'],
#  'Александр Доманицкий': ['Докладчики'],
#  'Александр Дубицкий': ['Докладчики'],
#  'Александр Дымо': ['Докладчики'],
#  'Александр Егоров': ['Докладчики'],
#  'Александр Епифанов': ['Докладчики'],
#  'Александр Зайцев': ['ContactOK', 'Докладчики'],
#  'Александр Иваненко': ['Докладчики'],
#  'Александр Казанский': ['Докладчики'],
#  'Александр Календарев': ['Докладчики'],
#  'Александр Калугин': ['Докладчики'],
#  'Александр Камкин': ['Докладчики'],
#  'Александр Кириллов': ['Докладчики'],
#  'Александр Кирсанов': ['Докладчики'],
#  'Александр Клыга': ['Докладчики'],
#  'Александр Клюкач': ['Докладчики'],
#  'Александр Княжев': ['Докладчики'],
#  'Александр Козачок': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Александр Козуб': ['Докладчики'],
#  'Александр Колесников': ['ContactOK', 'Докладчики'],
#  'Александр Кондаков': ['Докладчики'],
#  'Александр Кондратьев': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Александр Корепанов': ['Докладчики'],
#  'Александр Кормилицын': ['ContactOK', 'Докладчики'],
#  'Александр Коротков': ['Докладчики'],
#  'Александр Коршак': ['Докладчики'],
#  'Александр Кривенцов': ['Докладчики'],
#  'Александр Куликов': ['Докладчики'],
#  'Александр Куцан': ['Докладчики'],
#  'Александр Лазарев': ['Докладчики'],
#  'Александр Лазаренко': ['Докладчики'],
#  'Александр Лебедев': ['ContactOK', 'Докладчики'],
#  'Александр Легалов': ['Докладчики'],
#  'Александр Лесневский': ['Докладчики'],
#  'Александр Леушкин': ['Докладчики'],
#  'Александр Лопатин': ['Докладчики'],
#  'Александр Макаров': ['Докладчики'],
#  'Александр Марков': ['Докладчики'],
#  'Александр Мартюшев': ['Докладчики'],
#  'Александр Москвин': ['Докладчики'],
#  'Александр Наталенко': ['Докладчики'],
#  'Александр Неведовский': ['Докладчики'],
#  'Александр Ненашев': ['Докладчики'],
#  'Александр Николов': ['NeedContacts', 'Докладчики'],
#  'Александр Овчаренко': ['Докладчики'],
#  'Александр Онуфриев': ['Докладчики'],
#  'Александр Орлов': ['Докладчики'],
#  'Александр Оружейников': ['Докладчики'],
#  'Александр Павлов': ['Докладчики'],
#  'Александр Паздников': ['Докладчики'],
#  'Александр Панченко': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Александр Петренко': ['Докладчики'],
#  'Александр Половцев': ['Докладчики'],
#  'Александр Поносов': ['Докладчики'],
#  'Александр Попов': ['ContactOK', 'Докладчики'],
#  'Александр Прозоров': ['Докладчики'],
#  'Александр Ревяко': ['Докладчики'],
#  'Александр Рыжов': ['Докладчики'],
#  'Александр Рябиков': ['Докладчики'],
#  'Александр Рябинин': ['ContactOK', 'Докладчики'],
#  'Александр Самонов': ['ContactOK', 'Докладчики'],
#  'Александр Селяев': ['Докладчики'],
#  'Александр Сербул': ['Докладчики'],
#  'Александр Сороколетов': ['Докладчики'],
#  'Александр Сухинин': ['Докладчики'],
#  'Александр Титов': ['Докладчики'],
#  'Александр Тормасов': ['Докладчики'],
#  'Александр Трошин': ['Докладчики'],
#  'Александр Трубачев': ['NeedContacts', 'Докладчики'],
#  'Александр Турханов': ['Докладчики'],
#  'Александр Уланов': ['ContactOK', 'Докладчики'],
#  'Александр Федотов': ['Докладчики'],
#  'Александр Фролов': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Александр Хайдаров': ['Докладчики'],
#  'Александр Харкевич': ['Докладчики'],
#  'Александр Хрущев': ['Докладчики'],
#  'Александр Черный': ['Докладчики'],
#  'Александр Числер': ['Докладчики'],
#  'Александр Чистяков': ['Докладчики'],
#  'Александр Шалимов': ['Докладчики'],
#  'Александр Шарак': ['Докладчики'],
#  'Александр Шлянников': ['Докладчики'],
#  'Александр Щербаков': ['Докладчики'],
#  'Александр Яковлев': ['Докладчики'],
#  'Александр Яковлев™': ['Докладчики'],
#  'Александра Гавдаева': ['Докладчики'],
#  'Александра Кононова': ['Докладчики'],
#  'Александра Федорова': ['Докладчики'],
#  'Алексей Авдей': ['Докладчики'],
#  'Алексей Алексеев': ['Докладчики'],
#  'Алексей Алексеев™': ['Докладчики'],
#  'Алексей Арсеньев': ['Докладчики'],
#  'Алексей Асафьев': ['Докладчики'],
#  'Алексей Бабахин': ['Докладчики'],
#  'Алексей Бакушин': ['Докладчики'],
#  'Алексей Баранцев': ['Докладчики'],
#  'Алексей Бахиркин': ['Докладчики'],
#  'Алексей Бородкин': ['Докладчики'],
#  'Алексей Бугаев': ['ContactOK', 'Докладчики'],
#  'Алексей Васильев': ['Докладчики'],
#  'Алексей Вишняков': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Алексей Воронин': ['Докладчики'],
#  'Алексей Гапонов': ['ContactOK', 'Докладчики'],
#  'Алексей Горбунов': ['Докладчики'],
#  'Алексей Гореминский': ['Докладчики'],
#  'Алексей Демин': ['ContactOK', 'Докладчики'],
#  'Алексей Дерюшкин': ['Докладчики'],
#  'Алексей Дрожжов': ['Докладчики'],
#  'Алексей Дьяченко': ['Докладчики'],
#  'Алексей Евменков': ['Докладчики'],
#  'Алексей Ермаков': ['Докладчики'],
#  'Алексей Ерпелев': ['Докладчики'],
#  'Алексей Жеглов': ['Докладчики'],
#  'Алексей Журба': ['Докладчики'],
#  'Алексей Зиновьев': ['Докладчики'],
#  'Алексей Золотых': ['ContactOK', 'Докладчики'],
#  'Алексей Ильин': ['Докладчики'],
#  'Алексей Ильичев': ['Докладчики'],
#  'Алексей Казьмин': ['Докладчики'],
#  'Алексей Какунин': ['Докладчики'],
#  'Алексей Каленюк': ['Докладчики'],
#  'Алексей Канатов': ['ContactOK', 'Докладчики'],
#  'Алексей Колоколов': ['Докладчики'],
#  'Алексей Колотников': ['Докладчики'],
#  'Алексей Копылов': ['Докладчики'],
#  'Алексей Копытов': ['Докладчики'],
#  'Алексей Корецкий': ['Докладчики'],
#  'Алексей Косарчук': ['Докладчики'],
#  'Алексей Костарев': ['Докладчики'],
#  'Алексей Костин': ['Докладчики'],
#  'Алексей Котов': ['Докладчики'],
#  'Алексей Кривицкий': ['Докладчики'],
#  'Алексей Кузьмин': ['Докладчики'],
#  'Алексей Лаевский': ['Докладчики'],
#  'Алексей Лесных': ['Докладчики'],
#  'Алексей Лесовский': ['Докладчики'],
#  'Алексей Лосев': ['ContactOK', 'Докладчики'],
#  'Алексей Лустин': ['Докладчики'],
#  'Алексей Лянгузов': ['Докладчики'],
#  'Алексей Мариза': ['Докладчики'],
#  'Алексей Меандров': ['Докладчики'],
#  'Алексей Мицюк': ['Докладчики'],
#  'Алексей Москвин': ['Докладчики'],
#  'Алексей Надененко': ['Докладчики'],
#  'Алексей Новодворский': ['Докладчики'],
#  'Алексей Панев': ['Докладчики'],
#  'Алексей Петров': ['Докладчики'],
#  'Алексей Петров®': ['Докладчики'],
#  'Алексей Пикулев': ['Докладчики'],
#  'Алексей Пименов': ['Докладчики'],
#  'Алексей Прядко': ['Докладчики'],
#  'Алексей Пустыгин': ['ContactOK', 'Докладчики'],
#  'Алексей Рагозин': ['Докладчики'],
#  'Алексей Радецкий': ['Докладчики'],
#  'Алексей Рякин': ['Докладчики'],
#  'Алексей Семин': ['ContactOK', 'Докладчики'],
#  'Алексей Сиднев': ['Докладчики'],
#  'Алексей Синцов': ['Докладчики'],
#  'Алексей Скобелев': ['Докладчики'],
#  'Алексей Смирнов': ['Докладчики'],
#  'Алексей Солнцев': ['Докладчики'],
#  'Алексей Сорокин': ['Докладчики'],
#  'Алексей Спирков': ['ContactOK', 'Докладчики'],
#  'Алексей Сушков': ['Докладчики'],
#  'Алексей Тарасов': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Алексей Трошин': ['Докладчики'],
#  'Алексей Федорчук': ['ContactOK', 'Докладчики'],
#  'Алексей Филимонов': ['Докладчики'],
#  'Алексей Флоринский': ['Докладчики'],
#  'Алексей Фролов': ['Докладчики'],
#  'Алексей Фёдоров': ['Докладчики'],
#  'Алексей Хлебников': ['Докладчики'],
#  'Алексей Хорошилов': ['Докладчики'],
#  'Алексей Цветков': ['Докладчики'],
#  'Алексей Чеусов': ['Докладчики'],
#  'Алексей Чумаков': ['Докладчики'],
#  'Алексей Шабалин': ['Докладчики'],
#  'Алена Лысякова': ['Докладчики'],
#  'Алиса Комиссарова': ['ContactOK', 'Докладчики'],
#  'Алла Копылова': ['Докладчики'],
#  'Альберт Сорокин': ['NeedContacts', 'Докладчики'],
#  'Альберт Янов': ['Докладчики'],
#  'Алёна Кирдина': ['Докладчики'],
#  'Алёна Паньшина': ['Докладчики'],
#  'Анализ программ и систем': ['Верификация'],
#  'Анастасия Ащеулова': ['Докладчики'],
#  'Анастасия Ковалева-Геливер': ['Докладчики'],
#  'Анастасия Корнилова': ['ContactOK', 'Докладчики'],
#  'Анастасия Коханова': ['ContactOK', 'Докладчики'],
#  'Анастасия Кугач': ['Докладчики'],
#  'Анастасия Маркина': ['Докладчики'],
#  'Анастасия Мусина': ['Докладчики'],
#  'Анастасия Режепп': ['ContactOK', 'Докладчики'],
#  'Анастасия Шишова': ['Докладчики'],
#  'Анастасия Щеброва': ['Докладчики'],
#  'Анатолий Бабеня': ['Докладчики'],
#  'Анатолий Гребень': ['Докладчики'],
#  'Анатолий Заболотный': ['Докладчики'],
#  'Анатолий Зимин': ['Докладчики'],
#  'Анатолий Иванов': ['Докладчики'],
#  'Анатолий Коротков': ['Докладчики'],
#  'Анатолий Костин': ['Докладчики'],
#  'Анатолий Кушниренко': ['Докладчики'],
#  'Анатолий Левенчук': ['Докладчики'],
#  'Анатолий Рубцов': ['Докладчики'],
#  'Анатолий Сергеев': ['Докладчики'],
#  'Анатолий Суздальцев': ['Докладчики'],
#  'Анатолий Тыкушин': ['Докладчики'],
#  'Анатолий Харченко': ['Докладчики'],
#  'Анатолий Хомоненко': ['Докладчики'],
#  'Анатолий Шалыто': ['Докладчики'],
#  'Анатолий Шарифулин': ['Докладчики'],
#  'Анатолий Шкред': ['Докладчики'],
#  'Анатолий Якушин': ['Докладчики'],
#  'Андраш Густи': ['Докладчики'],
#  'Андрей Аксенов': ['Докладчики'],
#  'Андрей Андрианов': ['ContactOK', 'Докладчики'],
#  'Андрей Арефьев': ['Докладчики'],
#  'Андрей Бабанин': ['NeedContacts', 'Докладчики'],
#  'Андрей Бакаленко': ['Докладчики'],
#  'Андрей Балканский': ['Докладчики'],
#  'Андрей Басков': ['Докладчики'],
#  'Андрей Бешков': ['Докладчики'],
#  'Андрей Бибичев': ['Докладчики'],
#  'Андрей Бодренко': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Андрей Бордунов': ['Докладчики'],
#  'Андрей Бреслав': ['Докладчики'],
#  'Андрей Власовских': ['Докладчики'],
#  'Андрей Волков': ['Докладчики'],
#  'Андрей Волков™': ['Докладчики'],
#  'Андрей Воропай': ['Докладчики'],
#  'Андрей Галицкий': ['Докладчики'],
#  'Андрей Гевак': ['Докладчики'],
#  'Андрей Гордиенков': ['NeedContacts', 'Докладчики'],
#  'Андрей Григорьев': ['Докладчики'],
#  'Андрей Данилов': ['Докладчики'],
#  'Андрей Демичев': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Андрей Димитров': ['Докладчики'],
#  'Андрей Дмитриев': ['Докладчики'],
#  'Андрей Дунец': ['Докладчики'],
#  'Андрей Дюков': ['Докладчики'],
#  'Андрей Епихин': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Андрей Ефимов': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Андрей Заходяйченко': ['Докладчики'],
#  'Андрей Змушко': ['Докладчики'],
#  'Андрей Иванов': ['Докладчики'],
#  'Андрей Иванцов': ['Докладчики'],
#  'Андрей Индукаев': ['Докладчики'],
#  'Андрей Карпов': ['Докладчики'],
#  'Андрей Катухин': ['Докладчики'],
#  'Андрей Коновалов': ['ContactOK', 'Докладчики'],
#  'Андрей Конопля': ['Докладчики'],
#  'Андрей Кощеев': ['Докладчики'],
#  'Андрей Курьян': ['Докладчики'],
#  'Андрей Ланкин': ['Докладчики'],
#  'Андрей Логинов': ['Докладчики'],
#  'Андрей Логинов™': ['Докладчики'],
#  'Андрей Маглиас': ['Докладчики'],
#  'Андрей Майоров': ['Докладчики'],
#  'Андрей Малашенко': ['ContactOK', 'Докладчики'],
#  'Андрей Маркелов': ['Докладчики'],
#  'Андрей Мигальников': ['Докладчики'],
#  'Андрей Миронов': ['Докладчики'],
#  'Андрей Михайлов': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Андрей Михеев': ['ContactOK', 'Докладчики'],
#  'Андрей Могутов': ['Докладчики'],
#  'Андрей Мухаметов': ['Докладчики'],
#  'Андрей Мясников': ['Докладчики'],
#  'Андрей Неволин': ['Докладчики'],
#  'Андрей Ненахов': ['Докладчики'],
#  'Андрей Непрель': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Андрей Пономарев': ['Докладчики'],
#  'Андрей Пономаренко': ['Докладчики'],
#  'Андрей Ребров': ['Докладчики'],
#  'Андрей Ревуненко': ['Докладчики'],
#  'Андрей Родькин': ['Докладчики'],
#  'Андрей Романюк': ['Докладчики'],
#  'Андрей Сабынин': ['Докладчики'],
#  'Андрей Савченко': ['Докладчики'],
#  'Андрей Садовых': ['Докладчики'],
#  'Андрей Сапожников': ['Докладчики'],
#  'Андрей Свириденко': ['Докладчики'],
#  'Андрей Себрант': ['Докладчики'],
#  'Андрей Селедкин': ['Докладчики'],
#  'Андрей Сикорский': ['Докладчики'],
#  'Андрей Силаев': ['Докладчики'],
#  'Андрей Симонцев': ['Докладчики'],
#  'Андрей Слекеничс': ['ContactOK', 'Докладчики'],
#  'Андрей Смирнов': ['Докладчики'],
#  'Андрей Совцов': ['Докладчики'],
#  'Андрей Соснихин': ['Докладчики'],
#  'Андрей Степенко': ['Докладчики'],
#  'Андрей Столяров': ['Докладчики'],
#  'Андрей Татаранович': ['Докладчики'],
#  'Андрей Терехов': ['Докладчики'],
#  'Андрей Точилин': ['Докладчики'],
#  'Андрей Туркин': ['Докладчики'],
#  'Андрей Филев': ['Докладчики'],
#  'Андрей Холявкин': ['ContactOK', 'Докладчики'],
#  'Андрей Черепанов': ['Докладчики'],
#  'Андрей Черных': ['Докладчики'],
#  'Андрей Шадура': ['Докладчики'],
#  'Андрей Шевченко': ['Докладчики'],
#  'Андрей Шорин': ['Докладчики'],
#  'Андрей Ярошевский': ['Докладчики'],
#  'Аният Курбанова': ['Докладчики'],
#  'Анна Абрамова': ['Докладчики'],
#  'Анна Атрошкина': ['Докладчики'],
#  'Анна Беляева': ['Докладчики'],
#  'Анна Бирюкова': ['Докладчики'],
#  'Анна Галахова': ['Докладчики'],
#  'Анна Лопатухина': ['Докладчики'],
#  'Анна Мелехова': ['Докладчики'],
#  'Анна Мельничук': ['Докладчики'],
#  'Анна Мининкова': ['Докладчики'],
#  'Анна Обухова': ['Докладчики'],
#  'Анна Пенкина': ['Докладчики'],
#  'Анна Племяшова': ['ContactOK', 'Докладчики'],
#  'Анна Преображенская': ['Докладчики'],
#  'Анна Рид': ['Докладчики'],
#  'Анна Северинко': ['Докладчики'],
#  'Анна Сенькова': ['Докладчики'],
#  'Анна Скумина': ['Докладчики'],
#  'Анна Фофанова': ['Докладчики'],
#  'Анна Ходерян': ['ContactOK', 'Докладчики'],
#  'Анна Хотимская': ['Докладчики'],
#  'Антон Банчуков': ['Докладчики'],
#  'Антон Бевзюк': ['Докладчики'],
#  'Антон Белоусов': ['Докладчики'],
#  'Антон Бондарев': ['Докладчики'],
#  'Антон Волков': ['Докладчики'],
#  'Антон Гладкобородов': ['Докладчики'],
#  'Антон Дуканич': ['Докладчики'],
#  'Антон Зотин': ['Докладчики'],
#  'Антон Зуев': ['ContactOK', 'Докладчики'],
#  'Антон Иванов': ['Докладчики'],
#  'Антон Катков': ['Докладчики'],
#  'Антон Кекс': ['Докладчики'],
#  'Антон Кириллов': ['Докладчики'],
#  'Антон Котенко': ['Докладчики'],
#  'Антон Кругляков': ['Докладчики'],
#  'Антон Литвиненко': ['Докладчики'],
#  'Антон Литвинов': ['Докладчики'],
#  'Антон Мартынов': ['Докладчики'],
#  'Антон Марченко': ['Докладчики'],
#  'Антон Мидюков': ['Докладчики'],
#  'Антон Наумович': ['Докладчики'],
#  'Антон Новиков': ['Докладчики'],
#  'Антон Новиков™': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Антон Овчинников': ['Докладчики'],
#  'Антон Овчинников™': ['Докладчики'],
#  'Антон Орлов': ['Докладчики'],
#  'Антон Павлов': ['Докладчики'],
#  'Антон Семенченко': ['ContactOK', 'Докладчики'],
#  'Антон Сметанин': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Антон Толкунов': ['Докладчики'],
#  'Антон Уймин': ['Докладчики'],
#  'Антон Уткин': ['Докладчики'],
#  'Антон Фадеев': ['ContactOK', 'Докладчики'],
#  'Антон Хабурский': ['Докладчики'],
#  'Антон Хританков': ['Докладчики'],
#  'Антон Черников': ['Докладчики'],
#  'Антонина Рябуша': ['Докладчики'],
#  'Арег Мелик-Адамян': ['Докладчики'],
#  'Аркадий Кремер': ['ContactOK', 'Докладчики'],
#  'Аркадий Мурашев': ['ContactOK', 'Докладчики'],
#  'Арсений Кравченко': ['Докладчики'],
#  'Арсений Мешков': ['Докладчики'],
#  'Артем Глотов': ['Докладчики'],
#  'Артем Зырянов': ['Докладчики'],
#  'Артем Капнинский': ['Докладчики'],
#  'Артем Коломеец': ['Докладчики'],
#  'Артем Кувшинников': ['Докладчики'],
#  'Артем Кузнецов': ['Докладчики'],
#  'Артем Лабутин': ['ContactOK', 'Докладчики'],
#  'Артем Ломакин': ['Докладчики'],
#  'Артем Паньков': ['Докладчики'],
#  'Артем Семенов': ['Докладчики'],
#  'Артем Тихомиров': ['Докладчики'],
#  'Артур Арсенов': ['Докладчики'],
#  'Артур Орлов': ['Докладчики'],
#  'Артур Савченко': ['Докладчики'],
#  'Артур Тимофеев': ['Докладчики'],
#  'Артём Жиганов': ['Докладчики'],
#  'Артём Проскурнёв': ['Докладчики'],
#  'Артём Янцевич': ['NeedContacts', 'Докладчики'],
#  'Архитектура': ['Программная архитектура'],
#  'Архитектура информационных систем': ['Программная архитектура'],
#  'Архитектура серверных приложений': ['Программирование'],
#  'Асхат Уразбаев': ['Докладчики'],
#  'Аутентификация и авторизация': ['Информационная безопасность'],
#  'Аяз Ашрапов': ['Докладчики'],
#  'БПЛА': ['Робототехника'],
#  'Базы данных': ['Программирование', 'Хранение данных'],
#  'Байкал': ['Hardware'],
#  'Байрам Аннаков': ['Докладчики'],
#  'Безопасность': [],
#  'Бизнес-анализ': ['Темы'],
#  'Бизнес в IT': ['Темы'],
#  'Бизнес и СПО': ['Open-source'],
#  'Блиц-доклады': ['NotThemed'],
#  'Борис Вольфсон': ['Докладчики'],
#  'Борис Кузьмин': ['Докладчики'],
#  'Борис Макаренко': ['Докладчики'],
#  'Борис Новиков': ['Докладчики'],
#  'Борис Паньков': ['Докладчики'],
#  'Борис Позин': ['Докладчики'],
#  'Борис Седов': ['Докладчики', 'Страницы с неработающими файловыми ссылками'],
#  'Борис Славин': ['Докладчики'],
#  'Борис Штейнберг': ['Докладчики'],
#  'Вагиф Абилов': ['Докладчики'],
#  'Вадим Глебов': ['Докладчики'],
#  'Вадим Жуков': ['ContactOK', 'Докладчики'],
#  'Вадим Зубович': ['Докладчики'],
#  'Вадим Коротынский': ['Докладчики'],
#  'Вадим Кузнецов': ['Докладчики'],
#  'Вадим Мустяца': ['Докладчики'],
#  'Вадим Нарейко': ['Докладчики'],
#  'Вадим Подольный': ['Докладчики'],
#  'Вадим Реуцкий': ['Докладчики'],
#  'Вадим Рутковский': ['Докладчики'],
#  'Вадим Цесько': ['Докладчики'],
#  'Вадим Шамонин': ['Докладчики'],
#  'Вадим Шишкин': ['Докладчики'],
#  'Валентин Анопренко': ['Докладчики'],
#  'Валентин Макаров': ['Докладчики'],
#  'Валентин Малых': ['ContactOK', 'Докладчики'],
#  'Валентин Оносовский': ['Докладчики'],
#  'Валентина Крупадерова': ['Докладчики'],
#  'Валентина Ломаева': ['Докладчики'],
#  'Валентина Третьякова': ['Докладчики'],
#  'Валерий Бирин': ['Докладчики'],
#  'Валерий Егоров': ['Докладчики'],
#  'Валерий Иванов': ['Докладчики'],
#  'Валерий Иващенко': ['Докладчики'],
#  'Валерий Куваев': ['Докладчики'],
#  'Валерий Лаптев': ['ContactOK', 'Докладчики'],
#  'Валерий Ледовской': ['Докладчики'],
#  'Валерий Руденко': ['NeedContacts'],
#  'Валерия Безрукова': ['Докладчики'],
#  'Вартан Падарян': ['Докладчики'],
#  'Вартан Хачатуров': ['Докладчики'],
#  'Василий Васильков': ['Докладчики'],
#  'Василий Захаров': ['Докладчики'],
#  'Василий Курков': ['Докладчики'],
#  'Василий Литвинов': ['Докладчики'],
#  'Василий Меленчук': ['Докладчики'],
#  'Василий Михайлов': ['Докладчики'],
#  'Василий Моисеев': ['Докладчики'],
#  'Василий Сартаков': ['Докладчики'],
#  'Василий Слапик': ['Докладчики'],
#  'Василий Толстой': ['Докладчики'],
#  'Василий Чепцов': ['Докладчики'],
#  'Веб-дизайн': ['Дизайн'],
#  'Вебинары PingWin': [],
#  'Вера Карпова': ['Докладчики'],
#  'Верификация': ['Тестирование'],
#  'Видеосвязь': ['IP-телефония'],
#  'Визуализация': ['Юзабилити'],
#  'Викентий Лапа': ['Докладчики'],
#  'Виктор Батраев': ['Докладчики'],
#  'Виктор Бурховецкий': ['Докладчики'],
#  'Виктор Вальчук': ['Докладчики'],
#  'Виктор Волонтей': ['Докладчики'],
#  'Виктор Иванников': ['Докладчики'],
#  'Виктор Иванов': ['Докладчики'],
#  'Виктор Короневич': ['Докладчики'],
#  'Виктор Крапивенский': ['Докладчики'],
#  'Виктор Кузьмин': ['Докладчики'],
#  'Виктор Кулямин': ['ContactOK', 'Докладчики'],
#  'Виктор Ламбурт': ['Докладчики'],
#  'Виктор Наумов': ['Докладчики'],
#  'Виктор Стрелков': ['Докладчики'],
#  'Виктор Сычев': ['Докладчики'],
#  'Виктор Турский': ['Докладчики'],
#  'Виктор Филиппов': ['Докладчики'],
#  'Виктор Черногоров': ['Докладчики'],
#  'Виктор Яковлев': ['Докладчики'],
#  'Виктор Яковлев™': ['Докладчики'],
#  'Виктория Бабахина': ['Докладчики'],
#  'Виктория Корчагова': ['ContactOK', 'Докладчики'],
#  'Виктория Мозговая': ['Докладчики'],
#  'Виктория Пилипцевич': ['Докладчики'],
#  'Виктория Поляк': ['Докладчики'],
#  'Виктория Придатко': ['Докладчики'],
#  'Виктория Птицына': ['Докладчики'],
#  'Виктория Тарасова': ['Докладчики'],
#  'Виктория Черкалова': ['Докладчики'],
#  'Виртуализация': ['Программирование'],
#  'Виртуальный ассистент': ['NUI'],
#  'Виталий Антоненко': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Виталий Балашов': ['Докладчики'],
#  'Виталий Волобуев': ['Докладчики'],
#  'Виталий Воронович': ['Докладчики'],
#  'Виталий Герко': ['Докладчики'],
#  'Виталий Григораш': ['Докладчики'],
#  'Виталий Калмычков': ['Докладчики'],
#  'Виталий Камянский': ['Докладчики'],
#  'Виталий Козловский': ['Докладчики'],
#  'Виталий Король': ['Докладчики'],
#  'Виталий Липатов': ['Докладчики'],
#  'Виталий Лютиков': ['Докладчики'],
#  'Виталий Медведев': ['Докладчики'],
#  'Виталий Минко': ['Докладчики'],
#  'Виталий Обернихин': ['Докладчики'],
#  'Виталий Сороко': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Виталий Трифанов': ['Докладчики'],
#  'Виталий Филиппов': ['Докладчики'],
#  'Виталий Фридман': ['Докладчики'],
#  'Виталий Хилько': ['Докладчики'],
#  'Виталий Чепцов': ['ContactOK',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Виталий Черемисинов': ['Докладчики'],
#  'Виталий Шульга': ['Докладчики'],
#  'Влад Головач': ['Докладчики'],
#  'Влад Лялин': ['Докладчики'],
#  'Влад Шарпио': ['ContactOK', 'Докладчики'],
#  'Владимир Алексеев': ['Докладчики'],
#  'Владимир Атаманов': ['Докладчики'],
#  'Владимир Бахов': ['Докладчики'],
#  'Владимир Баяндин': ['Докладчики'],
#  'Владимир Белобородов': ['Докладчики'],
#  'Владимир Вахлов': ['Докладчики'],
#  'Владимир Главчев': ['Докладчики'],
#  'Владимир Горз': ['Докладчики'],
#  'Владимир Горовой': ['Докладчики'],
#  'Владимир Дрожжинов': ['Докладчики'],
#  'Владимир Железняк': ['Докладчики'],
#  'Владимир Завертайлов': ['Докладчики'],
#  'Владимир Запольский': ['Докладчики'],
#  'Владимир Зимин': ['Докладчики'],
#  'Владимир Иванов': ['ContactOK', 'Докладчики'],
#  'Владимир Ицыксон': ['Докладчики'],
#  'Владимир Кишик': ['Докладчики'],
#  'Владимир Климонтович': ['Докладчики'],
#  'Владимир Колесников': ['Докладчики'],
#  'Владимир Красильщик': ['Докладчики'],
#  'Владимир Купрацевич': ['Докладчики'],
#  'Владимир Ли': ['Докладчики'],
#  'Владимир Литошенко': ['ContactOK', 'Докладчики'],
#  'Владимир Мельник': ['Докладчики'],
#  'Владимир Николаев': ['Докладчики'],
#  'Владимир Оглоблин': ['Докладчики'],
#  'Владимир Половинский': ['Докладчики'],
#  'Владимир Прус': ['Докладчики'],
#  'Владимир Рубанов': ['Докладчики'],
#  'Владимир Рябчиков': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Владимир Селезнев': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Владимир Симонов': ['ContactOK', 'Докладчики'],
#  'Владимир Слыщенков': ['Докладчики'],
#  'Владимир Суховерхий': ['ContactOK', 'Докладчики'],
#  'Владимир Сухомлин': ['ContactOK', 'Докладчики'],
#  'Владимир Трубников': ['ContactOK', 'Докладчики'],
#  'Владимир Фофана': ['Докладчики'],
#  'Владимир Худяков': ['Докладчики'],
#  'Владимир Шпаковский': ['Докладчики'],
#  'Владимир Юнев': ['Докладчики'],
#  'Владислав Жолнерович': ['ContactOK', 'Докладчики'],
#  'Владислав Иванишин': ['Докладчики'],
#  'Владислав Кудинов': ['Докладчики'],
#  'Владислав Рябченко': ['ContactOK', 'Докладчики'],
#  'Владислав Степанов': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Владислав Чистяков': ['Докладчики'],
#  'Всеволод Котляров': ['Докладчики'],
#  'Всеволод Леонов': ['Докладчики'],
#  'Всеволод Родионов': ['Докладчики'],
#  'Встраиваемые системы': ['Программирование'],
#  'Выход на зарубежные рынки': ['Управление продуктами'],
#  'Вячеслав Борисов': ['Докладчики'],
#  'Вячеслав Васин': ['Докладчики'],
#  'Вячеслав Москаленко': ['Докладчики'],
#  'Вячеслав Нестеров': ['Докладчики'],
#  'Вячеслав Стародумов': ['NeedContacts',
#   'Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Геймификация': ['Agile process'],
#  'Геймификация в UX': ['UX', 'Геймификация', 'Управление продуктами'],
#  'Геннадий Драгун': ['Докладчики'],
#  'Геолокация': ['Программирование'],
#  'Георгий Быстренин': ['Докладчики'],
#  'Георгий Грибков': ['Докладчики'],
#  'Георгий Дюльдин': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Георгий Курячий': ['Докладчики'],
#  'Георгий Пчелинцев': ['ContactOK', 'Докладчики'],
#  'Георгий Савельев': ['Докладчики'],
#  'Георгий Савченко': ['ContactOK', 'Докладчики'],
#  'Герман Крюков': ['Докладчики'],
#  'Глеб Кудрявцев': ['Докладчики'],
#  'Глеб Луцков': ['Докладчики'],
#  'Глеб Рубанов': ['Докладчики'],
#  'Глеб Рыбалко': ['Докладчики'],
#  'Глеб Сологуб': ['Докладчики'],
#  'Глеб Фотенгауэр-Малиновский': ['Докладчики'],
#  'Голосовой интерфейс': ['NUI'],
#  'Госсектор': [],
#  'Государство и софт': ['IT-законы'],
#  'Графовые базы данных': ['Базы данных'],
#  'Григорий Волков': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Григорий Кондаков': ['Докладчики'],
#  'Григорий Печенкин': ['Докладчики'],
#  'Григорий Сенин': ['Докладчики'],
#  'Григорій Злобін': ['Докладчики'],
#  'Гульфия Курмангалеева': ['Докладчики'],
#  'Давид Бадалян': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Дамир Тенишев': ['Докладчики'],
#  'Даниил Батурин': ['Докладчики'],
#  'Даниил Березун': ['Докладчики'],
#  'Даниил Колесников': ['Докладчики'],
#  'Данил Асфандияров': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Данил Механошин': ['Докладчики'],
#  'Дария Потеряхина': ['Докладчики'],
#  'Дарья Куликова': ['Докладчики'],
#  'Дарья Сесицкая': ['Докладчики'],
#  'Дарья Федотова': ['Докладчики'],
#  'Денис Бесков': ['Докладчики'],
#  'Денис Блинов': ['Докладчики'],
#  'Денис Витман': ['Докладчики'],
#  'Денис Габидуллин': ['Докладчики'],
#  'Денис Гобов': ['Докладчики'],
#  'Денис Доронин': ['Докладчики'],
#  'Денис Доротенко': ['ContactOK', 'Докладчики'],
#  'Денис Дубров': ['ContactOK', 'Докладчики'],
#  'Денис Ефремов': ['Докладчики'],
#  'Денис Журавлев': ['Докладчики'],
#  'Денис Каланов': ['Докладчики'],
#  'Денис Коновалов': ['Докладчики'],
#  'Денис Кульбеда': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Денис Кулябин': ['Докладчики'],
#  'Денис Лутошкин': ['Докладчики',
#   'Страницы с неработающими файловыми ссылками'],
#  'Денис Макошенко': ['Докладчики'],
#  'Денис Медведев': ['Докладчики'],
#  'Денис Петров': ['Докладчики'],
#  'Денис Поповцев': ['Докладчики'],
#  'Денис Пынькин': ['Докладчики'],
#  ...}

# %%
def coalesce(dct, keys):
    for key in keys:
        if dct[key] is not None:
            return dct[key]
    return None


def parse_document_with_categories(doc):
    parsed_doc = dict()
    parsed_doc["title"] = doc["title"]
    parsed_doc['speakers'] = speaker_detect(doc['text'])
    
    sections_data = extract_sections(doc['text'])
    parsed_doc["annotation"] = sections_data["Аннотация"]
    parsed_doc["thesis"] = coalesce(
        sections_data, ["Thesis", "Тезисы", "Расширенные тезисы"]
    )
    
    parsed_doc['raw_categories'] = clear_categories(doc["categories"])
    parsed_doc["categories"] = list(
        filter(
            lambda x: x in ALL_CATEGORIES_WITHOUT_NAMES,
            parsed_doc['raw_categories'],
        )
    )
    return parsed_doc


data_raw = [parse_document_with_categories(doc) for doc in data['articles']]

# %% [markdown]
# Так как большие языковые модели довольно "умные", то можно спокойно опустить большую часть фильтрации текста.
#
# Причём, если эту фильтрацию оставить, то полученные эмбеддинги окажутся не такими хорошими, поскольку обработанный текст менее логичен и связен, в отличии от естественного языка.
#
# Тем не менее, мы оставим некоторые фильтры: это удаление ссылок и сохранение токена <sep> между разными модальностями
#
# Очистка текста:
# - удаление ссылок
# - удаление всех HTML тегов

# %%
def clean_text_for_llm(text):
    if text is None or len(text) == 0:
        return ""

    text = re.sub(r"<[^>]+>", "", text)
    text = re.sub(r"http\S+|www\.\S+", "", text)

    # Remove LaTeX commands and symbols
    text = re.sub(r'\\[a-zA-Z]+\s*({.*?})?', '', text)
    text = re.sub(r'\{.*?\}', '', text)

    # Remove special characters and excessive whitespace
    text = re.sub(r'[^a-zA-Zа-яА-Я0-9\s.,<>:;\'\"()\[\]\-—]', ' ', text)
    text = re.sub(r'\s+', ' ', text)

    return text


def clean_and_merge_document_for_llm(doc, sep_token=SEP_TOKEN):
    cleaned_texts = []

    # Clean each field and collect non-empty results
    for field in ["title", "annotation", "thesis"]:
        field_text = doc.get(field, "")
        cleaned_tokens = clean_text_for_llm(field_text)

        if cleaned_tokens:
            cleaned_texts.append(cleaned_tokens)

    # Join with <sep> token
    result_text = f" {sep_token} ".join(cleaned_texts).strip()

    result = {
        "text": result_text,
        "categories": doc.get("categories", []),
        "raw_categories": doc.get("raw_categories", []),
        "speakers": doc.get("speakers", []),
    }

    return result


# Example usage
text = """
<html>Пример текста. Это тестовый текст с примером <a href="http://example.com">ссылки</a>.
Вот еще ссылка: https://www.test.ru.
Здесь есть часто-встречающиеся слова, например, "тест" много раз.
...
Также нужно удалить .эти строки.
"""

print(clean_text_for_llm(text))
print(clean_and_merge_document_for_llm(data_raw[1298]))
# Out:
#  Пример текста. Это тестовый текст с примером ссылки. Вот еще ссылка: Здесь есть часто-встречающиеся слова, например, "тест" много раз. ... Также нужно удалить .эти строки.
# {'text': 'Маркетинг мобильных приложений (Юрий Мельничек, SECR-2015) <sep> Я руковожу MAPS.ME с самого начала и до 25 миллионов инсталляций на текущий момент. За это время у меня сформировался системный взгляд на маркетинг мобильных приложений, которым я и поделюсь со слушателями: Какие существуют маркетинговые каналы для раскрутки мобильных приложений (PR, ASO, реклама, фичеринги и т.д). Как работать с каждым из них. Какой путь проходят пользователи до инсталляции приложения. Как увеличить конверсию. Какие есть инструменты мобильного маркетинга. Какое положение маркетинга в бизнес-стратегии мобильного приложения. Доклад будет интересен маркетологам, топ-менеджерам и разработчикам мобильных приложений.', 'categories': ['Мобильная разработка', 'Управление продуктами'], 'raw_categories': ['HasSpeaker', 'SECR-2015', 'Мобильная разработка', 'Управление продуктами', 'Юрий Мельничек'], 'speakers': ['Юрий Мельничек']}

# %% [markdown]
# Process text

# %%
processed_data = [clean_and_merge_document_for_llm(doc) for doc in data_raw]

# %%
text_lengths = list(map(len, [elem['text'] for elem in processed_data]))
pd.Series(text_lengths).describe()
# Out:
# count     2541.000000
# mean      1327.888233
# std       2120.183248
# min          2.000000
# 25%        282.000000
# 50%        623.000000
# 75%       1153.000000
# max      20089.000000
# dtype: float64

# %% [markdown]
# ## Prompt engineering for topic summary

# %% [markdown]
# ### Utils

# %%
OLLAMA_CONFIG = {
    "keep_alive": "2m",
    "stream": False,
}

SYSTEM_PROMPT = (
    "You are an AI assistant tasked with generating precise and concise topic titles. "
    "Do not include explanations or reasoning—only provide the final title for each topic. "
    "Write answer in Russian language, but if there are foreign terms leave them as is."
)

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
def run_prompt(endpoint, prompt, model='gemma2', temperature=0, seed=123, **kwargs):
    options_config = {"temperature": temperature, "seed": seed, **kwargs}

    combined_prompt = f"{SYSTEM_PROMPT}\n\n{prompt}"

    payload = {
        **OLLAMA_CONFIG,
        "model": model,
        "prompt": combined_prompt,
        "options": options_config
    }

    response = httpx.post(
        endpoint,
        json=payload,
        headers={"Content-Type": "application/json"},
        timeout=300,
    )
    
    if response.status_code != 200:
        print("Error", response.status_code)
        assert(False)

    return response


def debug_prompt(prompt, endpoint='http://127.0.0.1:11434/api/generate', model='gemma2', **kwargs):
    text = re.compile(r'#[^\n]*').sub('', prompt).strip()
    response = run_prompt(endpoint, text, model, **kwargs)
    response_content = response.json().get('response', 'No response found.')
    
    print(response_content)

# %% [markdown]
# ### Examples

# %%
# !ollama list
# Out:
# NAME                               ID              SIZE      MODIFIED
# rscr/ruadapt_qwen2.5_32b:Q8_0      9907b3df7370    34 GB     7 days ago
# mistral:latest                     f974a74358d6    4.1 GB    2 weeks ago
# llama3:latest                      365c0bd3c000    4.7 GB    2 weeks ago
# aya-expanse:latest                 65f986688a01    5.1 GB    7 weeks ago
# gemma2:latest                      ff02c3702f32    5.4 GB    7 weeks ago
# gemma2:27b                         53261bc9c192    15 GB     2 months ago
# mistral-large:latest               0ca7dfa0bf06    69 GB     2 months ago
# deepseek-v2.5:latest               409b2dd8a3c4    132 GB    2 months ago
# dolphin-mixtral:latest             cfada4ba31c7    26 GB     8 months ago
# codellama:latest                   8fdf8f752f6e    3.8 GB    8 months ago
# llama2:latest                      78e26419b446    3.8 GB    8 months ago
# mistral:7b-instruct-v0.2-q4_K_S    ba00d3a5239e    4.1 GB    9 months ago
# codellama:13b                      9f438cb9cd58    7.4 GB    9 months ago

# %% [markdown]
# Большие модели (больше 15 GB) долго инференсятся: это `mistral-large`, `deepseek-v2.5`, `dolphin-mixtral`. Поэтому их мы отбросим
#
# Также из рассмотрения исключены `codellama` из-за ошибки 404 в API

# %%
models_list = (
    'llama3',
    'mistral',
    'aya-expanse',
    'gemma2',
    'gemma2:27b',
    'llama2',
    'mistral:7b-instruct-v0.2-q4_K_S',
    'codellama:13b'
)

for model in models_list:
    print(model)
    debug_prompt("""
    Ты редактор википедии. 
    Прочти текст ''' 
    «Ковидный период» и недавно наступившая «эра перемен» сильно подстегнула ВУЗовское дистанционное образование. Раньше нормой были «оффлайн» занятия, если повезло, поддерживаемые книжкой лектора, видеозаписями лекций-семинаров, а «дистанционка» была скорее редко терпимым исключением. Сейчас же нормой становится ситуация, когда преподаватель и даже студенты разбросаны по всему миру. Но мало, созвонившись в каком-нибудь zoom-е, начать читать лекцию, и, заглядывая в чёрные квадратики отключённых видеокамер, пытаться понять, слышат ли преподавателя студенты и вообще, что они делают, мучительно надеясь вовлечь их в процесс. Увы, это просто не работает. Ещё хуже с домашней работой — мало давать студентам «книгу» и надеятся, что они её прочтут — всё в этом устаревшем формате (объём, статичность, неудобство «листов», неинтерактивность, неверифицируемость) неэффективно по современным меркам.

    Да, есть масса онлайн сервисов, которые уже долгое время помогали айтишникам и студентам во время созвонов, и которые стали ещё популярнее в «ковидную эру» — разделяемые онлайн доски и документы, гугл-доки и гугл-колаб-ноутбуки, … но после «войны взаимных интернет-блокировок и санкций» на них нельзя расчитывать. Например, в РФ программа «Google Suite for Education» закрылась из-за анти-РФ санкций, с другой стороны, десятки и сотни сервисов перестали работать только из-за того, что использовали кеширование и балансировку через сервис Сloudflare (запрещается РКН). Ситуация продолжает ухудшаться, перспективы неутешительны.

    Только системы с открытым кодом, поднятые на своей инфраструктуре, предсказуемы и защищены от этих «блокад» — блокировок и санкций. Мы расскажем именно о таких системах, успешно применяемых и развиваемых автором при преподавании математических и алгоритмических курсов в ИСПРАН и МФТИ и ведении исследовательской и научной работы в отделе математических методов и алгоритмов ИСПРАН.

    Системы для организации созвонов, «интерактивные доски», системы для одновременного совместного редактирования кода и текстов, «коллаборативные блокноты»… организуют и «классную» и «внеклассную» работы, граница между которыми уже размыта по всему, что как-то связано с математикой и алгоритмами. А их использование позволяет делать новые типы образовательного контента — на замену унылым толстым книжкам и уродливым слайдам приходят «живые лаборатории» с компактными интерактивными материалами, с которыми можно и «поиграть», и привлечь студентов к совместному творчеству нового.
    '''
    Выведи категорию, к которой эта статья относится.
    """, model=model)
    print('='*80)
# Out:
# llama3
# 2024-12-30 05:25:39,271 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# «Образование в эру цифровых технологий»
# ================================================================================
# mistral
# 2024-12-30 05:25:41,563 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  Категория: "Онлайн-образование" или "Использование технологий в образовании"
# ================================================================================
# aya-expanse
# 2024-12-30 05:25:45,993 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# # Дистанционное обучение в эпоху COVID-19: возможности и вызовы систем с открытым кодом
#
# Категория: Образование, Технологии, Открытый исходный код
# ================================================================================
# gemma2
# 2024-12-30 05:25:49,753 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Образование
#
# ================================================================================
# gemma2:27b
# 2024-12-30 05:26:02,666 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Дистанционное образование в ВУЗах с открытым исходным кодом
#
# ================================================================================
# llama2
# 2024-12-30 05:26:05,464 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Категория: Образование
# ================================================================================
# mistral:7b-instruct-v0.2-q4_K_S
# 2024-12-30 05:26:08,536 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  Эта статья относится к категории "Онлайн-обучение" или "Интерактивные системы для обучения".
# ================================================================================
# codellama:13b
# 2024-12-30 05:26:12,206 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Компьютерные науки
# ================================================================================

# %% [markdown]
# Лучше себя показали `llama3`, `mistral`, `gemma2:27b`, `mistral:7b-instruct-v0.2-q4_K_S`
#
# У `codellama:13b` совсем дурной выход, поэтому не будем её дальше рассматривать

# %% [markdown]
# ### Модифицированный промпт

# %%
SUMMARIZING_PROMPT = """
    You are an AI language model designed to analyze topics defined by keywords, bigrams, and categories, and then summarize each topic into a concise, descriptive name. Use the provided information (keywords, bigrams, and categories) to infer the central theme of each topic and generate a short, meaningful title. Follow these guidelines:

    1. Focus on the most relevant and representative keywords and bigrams to identify the primary subject of the topic.
    2. Use the categories to refine and contextualize the theme.
    3. Avoid overly generic titles; aim for specificity and clarity.
    4. Ensure the title reflects the core idea that unites the keywords, bigrams, and categories.

    Here is the input format:
    ```
    Topic: [topic_name]
    Words: [list of words]
    Bigrams: [list of bigrams]
    Categories: [list of categories]
    ```

    And here is an example of the desired output:
    ```
    Input:
    Topic: topic_15
    Words: ['архитектура', 'код', 'платформа', 'сервис', 'технология']
    Bigrams: ['хранилище_данные', 'облачный_сервис', 'распределённый_система', 'модуль_ядро', 'обработка_больший']
    Categories: ['программирование', 'программная_архитектура', 'распределенные_системы', 'виртуализация', 'paas']

    Output:
    "topic_15": "Архитектура программ и облачные сервисы"

    Input:
    Topic: topic_16
    Words: ['модель', 'текст', 'анализ', 'метод', 'алгоритм']
    Bigrams: ['ред_база', 'учебный_материал', 'субд_ред', 'вычислительный_комплекс', 'анализ_текст']
    Categories: ['алгоритмы', 'наука', 'machine_learning', 'natural_language_processing', 'data_analysis']

    Output:
    "topic_16": "Модели и алгоритмы анализа текста"

    Input:
    Topic: topic_17
    Words: ['проблема', 'требование', 'оценка', 'качество', 'заказчик']
    Bigrams: ['управление_требование', 'больший_количество', 'совместный_работа', 'оценка_качество', 'реализация_проект']
    Categories: ['бизнес_анализ', 'процесс_тестирования', 'управление_требованиями', 'дизайн', 'team_communication']

    Output:
    "topic_17": "Управление требованиями и дизайн"

    Input:
    Topic: topic_18
    Words: ['являться', 'любой', 'образ', 'позволять', 'часть']
    Bigrams: ['возможность_использование', 'высокий_уровень', 'данный_подход', 'код_проект', 'адресный_пространство']
    Categories: ['программирование', 'java', 'разработка_операционных_систем', 'моделирование_бизнес_процессов', 'доклад_со_стенограммой']

    Output:
    "topic_18": "Подходы в программировании и моделировании"

    Input:
    Topic: topic_19
    Words: ['компания', 'технический', 'российский', 'развитие', 'россия']
    Bigrams: ['команда_разработчик', 'ит_компания', 'технический_писатель', 'свой_проект', 'технический_долг']
    Categories: ['agile_process', 'государство_и_софт', 'документирование', 'спо_в_россии', 'планирование']

    Output:
    "topic_19": "Технические проекты в России"
    ```

    Now, process the following topics and generate titles for each:
"""

# %%
top_tokens_lvl0_arr = list(map(lambda x: x.strip(), top_tokens_lvl0.split('='*80)))
top_tokens_lvl1_arr = list(map(lambda x: x.strip(), top_tokens_lvl1.split('='*80)))

top_tokens_lvl0_arr = np.array(list(filter(None, top_tokens_lvl0_arr)))
top_tokens_lvl1_arr = np.array(list(filter(None, top_tokens_lvl1_arr)))

np.random.seed(123)
lvl0_rand_ids = np.random.choice(len(top_tokens_lvl0_arr), 2, replace=False)
lvl1_rand_ids = np.random.choice(len(top_tokens_lvl1_arr), 2, replace=False)

rand_samples = list(
    itertools.chain(
        *[
            top_tokens_lvl0_arr[lvl0_rand_ids],
            top_tokens_lvl1_arr[lvl1_rand_ids]
        ]
    )
)
rand_samples_gpt_target = list(
    itertools.chain(
        *[
            gpt_output_lvl0[lvl0_rand_ids],
            gpt_output_lvl1[lvl1_rand_ids]
        ]
    )
)

# %%
models_list_v2 = (
    'llama3',
    'mistral',
    'aya-expanse',
    'gemma2',
    'gemma2:27b',
    'llama2',
    'mistral:7b-instruct-v0.2-q4_K_S',
)

print(*rand_samples, sep='\n')
print('\n')
print(*rand_samples_gpt_target, sep='\n')
print('\n\n')

for model in models_list_v2:
    print(model)
    
    for rand_sample in rand_samples:
        debug_prompt(SUMMARIZING_PROMPT + f"```\n{rand_sample}\n```", model=model)
    
    print('='*80)
# Out:
# Topic: topic_14
#     Words: ['системный', 'ядро', 'вызов', 'версия', 'сборка']
#     Bigrams: ['начинать_версия', 'версия_выпустить', 'fault_injection', 'накладный_расход', 'версия_ядро']
#     Categories: ['системное_администрирование', 'devops', 'agile__технологические_практики', 'анализ_программ_и_систем', 'статический_анализ_кода']
# Topic: topic_5
#     Words: ['пакет', 'дистрибутив', 'объект', 'состояние', 'рамка']
#     Bigrams: ['использование_технология', 'рамка_доклад', 'подход_решение', 'сложный_задача', 'проблема_являться']
#     Categories: ['параллельное_программирование', 'linux_дистрибутивы', 'alt_linux', 'linux_дистрибутивы_для_enterprise', 'ui']
# Topic: topic_4
#     Words: ['данные', 'бд', 'база', 'обработка', 'файл']
#     Bigrams: ['база_данные', 'обработка_данные', 'принимать_решение', 'головной_боль', 'приложение_позволять']
#     Categories: ['конференции', 'front_end_development', 'собрания_altnet']
# Topic: topic_90
#     Words: ['код', 'должный', 'реализация', 'полный', 'важно']
#     Bigrams: ['официальный_сайт', 'пример_реализация', 'режим_реальный', 'передача_данные', 'платформа_альт']
#     Categories: ['agile__технологические_практики', 'bdd', 'code_review', 'мастер_классы', 'рефакторинг']
#
#
# ['topic_14' 'Системные вызовы и ядро Linux']
# ['topic_5' 'Дистрибутивы Linux и сложные задачи']
# ['topic_4' 'Базы данных и обработка данных']
# ['topic_90' 'Рефакторинг и тестирование кода']
#
#
#
# llama3
# 2024-12-20 13:52:57,734 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_14": "Системное администрирование и версии ядра"
# 2024-12-20 13:52:58,421 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_5": "Пакеты и дистрибутивы Linux"
# 2024-12-20 13:52:58,959 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_4": "Обработка и анализ данных в базе"
# 2024-12-20 13:52:59,586 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_90": "Реализация кода и официальный сайт"
# ================================================================================
# mistral
# 2024-12-20 13:53:01,980 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_14": "Сборка ядра и версионирование в DevOps"
# 2024-12-20 13:53:02,657 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_5": "Пакеты и рамки параллельного программирования в Linux"
# 2024-12-20 13:53:03,334 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_4": "Обработка данных и базы в front-end разработке"
# 2024-12-20 13:53:03,954 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_90": "Ключевые практики реализации кода"
# ================================================================================
# aya-expanse
# 2024-12-20 13:53:08,179 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_14": "Управление версиями и системный анализ с акцентом на DevOps"
# 2024-12-20 13:53:08,992 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_5": "Параллельное программирование и распределённые системы в Linux-дистрибутивах"
# 2024-12-20 13:53:09,683 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_4": "Управление данными и базы данных в веб-разработке"
# 2024-12-20 13:53:10,434 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_90": "Важность полного кода и рефакторинга в Agile-практиках"
# ================================================================================
# gemma2
# 2024-12-20 13:53:14,530 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_14": "Разработка и тестирование ядра систем"
# 2024-12-20 13:53:15,284 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_5": "Дистрибутивы Linux и параллельное программирование"
# 2024-12-20 13:53:15,962 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_4": "Обработка данных и базы данных"
# 2024-12-20 13:53:16,681 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_90": "Реализация кода и BDD практики"
#
#
#
# ================================================================================
# gemma2:27b
# 2024-12-20 13:53:31,958 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_14": "Версии ядра и системное администрирование"
# 2024-12-20 13:53:40,811 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_5": "Дистрибутивы Linux и Параллельное Программирование"
# 2024-12-20 13:53:47,920 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_4": "Обработка данных и базы данных"
# 2024-12-20 13:53:55,574 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# "topic_90": "Реализация кода и практики BDD"
#
# ================================================================================
# llama2
# 2024-12-20 13:53:58,845 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Topic: topic_14
# Title: "Системное администрирование и версия control"
# 2024-12-20 13:54:01,965 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Input:
# Topic: topic_5
# Words: ['пакет', 'дистрибутив', 'объект', 'состояние', 'рамка']
# Bigrams: ['использование_технология', 'рамка_доклад', 'подход_решение', 'сложный_задача', 'проблема_являться']
# Categories: ['параллельное_программирование', 'linux_дистрибутивы', 'alt_linux', 'linux_дистрибутивы_для_enterprise', 'ui']
#
# Output:
# "topic_5": "Использование технологий в параллельном программировании"
# 2024-12-20 13:54:02,598 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Topic: topic_4
# Title: "Обработка данных в базе и приложениях"
# 2024-12-20 13:54:03,307 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Topic: topic_90
# Title: "Официальный сайт и реальная реализация кода"
# ================================================================================
# mistral:7b-instruct-v0.2-q4_K_S
# 2024-12-20 13:54:06,339 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_14": "Сборка ядерных версий: системное администрирование"
# 2024-12-20 13:54:25,060 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_5": "Пакеты и рамы для дистрибутивов Linux"
#
# ```russian
# Topic: topic_6
#     Words: ['пользовательский', 'интерфейс', 'оптимизация', 'производительность', 'приложение']
#     Bigrams: ['создание_приложения', 'высокая_производительность', 'оптимизация_пользовательский_интерфейс', 'работа_приложением', 'интерактивный_интерфейс']
#     Categories: ['ui_design', 'web_development', 'mobile_app_development', 'программное_обеспечение', 'performance']
#
# Output:
# "topic_6": "Разработка приложений с оптимизированным пользовательским интерфейсом"
# ```
#
# ```russian
# Topic: topic_7
#     Words: ['процесс', 'технология', 'инновация', 'развитие', 'система']
#     Bigrams: ['инновационный_процесс', 'технология_разработки_предметно-ориентированных_систем', 'расширенная_версия_процесса', 'создание_система', 'постоянное_улучшение']
#     Categories: ['software_engineering', 'agile_methodologies', 'systems_design', 'project_management', 'continuous_improvement']
#
# Output:
# "topic_7": "Инновационные процессы и развитие систем"
# ```
#
# ```russian
# Topic: topic_8
#     Words: ['программа', 'консоль', 'пользовательский', 'интерфейс', 'оптимизация']
#     Bigrams: ['пользовательский_интерфейс_консоли', 'высокая_производительность_программы', 'оптимизация_работы_в_консоли', 'работа_с_программой_консолью', 'пользовательский_интерфейс_текстовой']
#     Categories: ['command_line_interface', 'performance_optimization', 'ui_design', 'software_development', 'terminal']
#
# Output:
# "topic_8": "Работа с консолью и оптимизация производительности программы"
# ```
#
# ```russian
# Topic: topic_9
#     Words: ['процесс', 'технология', 'инновация', 'развитие', 'система']
#     Bigrams: ['инновационный_процесс_разработки_систем', 'технология_создания_систем', 'постоянное_улучшение_процесса', 'создание_системы_для_бизнеса', 'расширенная_версия_процесса']
#     Categories: ['systems_engineering', 'agile_methodologies', 'project_management', 'business_processes', 'continuous_improvement']
#
# Output:
# "topic_9": "Разработка систем с инновационными процессами и постоянным улучшением"
# ```
#
# ```russian
# Topic: topic_10
#     Words: ['процесс', 'технология', 'инновация', 'развитие', 'система']
#     Bigrams: ['инновационный_процесс_создания_систем', 'технология_построения_систем', 'постоянное_улучшение_процесса_разработки', 'создание_системы_для_расширения_возможностей', 'инновационные_принципы_процесса']
#     Categories: ['systems_engineering', 'agile_methodologies', 'project_management', 'technology_trends', 'continuous_improvement']
#
# Output:
# "topic_10": "Создание инновационных систем с постоянно улучшающимися процессами"
# ```
# 2024-12-20 13:54:26,439 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_4": "Обработка данных в базах и приложениях"
# 2024-12-20 13:54:27,187 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
#  "topic_90": "Важная реализация кода в практиках Agile и BDD"
# ================================================================================

# %% [markdown]
# Форматированный вывод + комментарии
#
# #### **gpt-4o**
# - `"topic_14": "Системные вызовы и ядро Linux"`
# - `"topic_5": "Дистрибутивы Linux и сложные задачи"`
# - `"topic_4": "Базы данных и обработка данных"`
# - `"topic_90": "Рефакторинг и тестирование кода"`
#
# Бейзлайн
#
# #### **llama3**
# - `"topic_14": "Системное администрирование и версии ядра"`
# - `"topic_5": "Пакеты и дистрибутивы Linux"`
# - `"topic_4": "Обработка и анализ данных в базе"`
# - `"topic_90": "Реализация кода и официальный сайт"`
#
# Названия 3 и 4 кривые -- не подходит
#
# #### **mistral**
# - `"topic_14": "Сборка ядра и версионирование в DevOps"`
# - `"topic_5": "Пакеты и рамки параллельного программирования в Linux"`
# - `"topic_4": "Обработка данных и базы в front-end разработке"`
# - `"topic_90": "Ключевые практики реализации кода"`
#
# Названия 2-4 кривые -- не подходит
#
# #### **aya-expanse**
# - `"topic_14": "Управление версиями и системный анализ с акцентом на DevOps"`
# - `"topic_5": "Параллельное программирование и распределённые системы в Linux-дистрибутивах"`
# - `"topic_4": "Управление данными и базы данных в веб-разработке"`
# - `"topic_90": "Важность полного кода и рефакторинга в Agile-практиках"`
#
# Очень развёрнуто, класс
#
# #### **gemma2**
# - `"topic_14": "Разработка и тестирование ядра систем"`
# - `"topic_5": "Дистрибутивы Linux и параллельное программирование"`
# - `"topic_4": "Обработка данных и базы данных"`
# - `"topic_90": "Реализация кода и BDD практики"`
#
# Норм
#
# #### **gemma2:27b**
# - `"topic_14": "Версии ядра и системное администрирование"`
# - `"topic_5": "Дистрибутивы Linux и Параллельное Программирование"`
# - `"topic_4": "Обработка данных и базы данных"`
# - `"topic_90": "Реализация кода и практики BDD"`
#
# Норм
#
# #### **llama2**
# - `"topic_14": "Системное администрирование и версия control"`
# - `"topic_5": "Использование технологий в параллельном программировании"`
# - `"topic_4": "Обработка данных в базе и приложениях"`
# - `"topic_90": "Официальный сайт и реальная реализация кода"`
#
# Все названия, кроме 2-го, звучат криво -- не подходит
#
# #### **mistral:7b-instruct-v0.2-q4_K_S**
# - `"topic_14": "Сборка ядерных версий: системное администрирование"`
# - `"topic_5": "Пакеты и рамы для дистрибутивов Linux"`
# - `"topic_4": "Обработка данных в базах и приложениях"`
# - `"topic_90": "Важная реализация кода в практиках Agile и BDD"`
#
# Вывела какую-то хрень в промежутке между ответами, названия звучат криво -- не подходит

# %% [markdown]
# По итогу, остались 3 модели -- `aya-expanse`, `gemma2`, `gemma2:27b`
#
# Рекомендую использовать `gemma2`, так как она легковесная + её названия лаконичны по сравнению с `gemma2:27b`

# %% [markdown]
# ### Итоговый пайплайн

# %%
OLLAMA_CONFIG = {
    "keep_alive": "2m",
    "stream": False,
}

SYSTEM_PROMPT = (
    "You are an AI assistant tasked with generating precise and concise topic titles. "
    "Do not include explanations or reasoning—only provide the final title for each topic. "
    "Write answer in Russian language, but if there are foreign terms leave them as is."
)

SUMMARIZING_PROMPT = """
    You are an AI language model designed to analyze topics defined by keywords, bigrams, and categories, and then summarize each topic into a concise, descriptive name. Use the provided information (keywords, bigrams, and categories) to infer the central theme of each topic and generate a short, meaningful title. Follow these guidelines:

    1. Focus on the most relevant and representative keywords and bigrams to identify the primary subject of the topic.
    2. Use the categories to refine and contextualize the theme.
    3. Avoid overly generic titles; aim for specificity and clarity.
    4. Ensure the title reflects the core idea that unites the keywords, bigrams, and categories.

    Here is the input format:
    ```
    Topic: [topic_name]
    Words: [list of words]
    Bigrams: [list of bigrams]
    Categories: [list of categories]
    ```

    And here is an example of the desired output:
    ```
    Input:
    Topic: topic_15
    Words: ['архитектура', 'код', 'платформа', 'сервис', 'технология']
    Bigrams: ['хранилище_данные', 'облачный_сервис', 'распределённый_система', 'модуль_ядро', 'обработка_больший']
    Categories: ['программирование', 'программная_архитектура', 'распределенные_системы', 'виртуализация', 'paas']

    Output:
    "topic_15": "Архитектура программ и облачные сервисы"

    Input:
    Topic: topic_16
    Words: ['модель', 'текст', 'анализ', 'метод', 'алгоритм']
    Bigrams: ['ред_база', 'учебный_материал', 'субд_ред', 'вычислительный_комплекс', 'анализ_текст']
    Categories: ['алгоритмы', 'наука', 'machine_learning', 'natural_language_processing', 'data_analysis']

    Output:
    "topic_16": "Модели и алгоритмы анализа текста"

    Input:
    Topic: topic_17
    Words: ['проблема', 'требование', 'оценка', 'качество', 'заказчик']
    Bigrams: ['управление_требование', 'больший_количество', 'совместный_работа', 'оценка_качество', 'реализация_проект']
    Categories: ['бизнес_анализ', 'процесс_тестирования', 'управление_требованиями', 'дизайн', 'team_communication']

    Output:
    "topic_17": "Управление требованиями и дизайн"

    Input:
    Topic: topic_18
    Words: ['являться', 'любой', 'образ', 'позволять', 'часть']
    Bigrams: ['возможность_использование', 'высокий_уровень', 'данный_подход', 'код_проект', 'адресный_пространство']
    Categories: ['программирование', 'java', 'разработка_операционных_систем', 'моделирование_бизнес_процессов', 'доклад_со_стенограммой']

    Output:
    "topic_18": "Подходы в программировании и моделировании"

    Input:
    Topic: topic_19
    Words: ['компания', 'технический', 'российский', 'развитие', 'россия']
    Bigrams: ['команда_разработчик', 'ит_компания', 'технический_писатель', 'свой_проект', 'технический_долг']
    Categories: ['agile_process', 'государство_и_софт', 'документирование', 'спо_в_россии', 'планирование']

    Output:
    "topic_19": "Технические проекты в России"
    ```

    Now, process the following topics and generate titles for each:
"""


logging.disable(logging.INFO)

def execute_prompt(prompt, endpoint='http://127.0.0.1:11434/api/generate', model='gemma2', **kwargs):
    text = re.compile(r'#[^\n]*').sub('', prompt).strip()
    response = run_prompt(endpoint, text, model, **kwargs)
    response_content = response.json().get('response', 'No response found.')
    return response_content

# %%
lvl0_titles = []
lvl1_titles = []

for sample in tqdm.tqdm(top_tokens_lvl0_arr):
    outp = execute_prompt(SUMMARIZING_PROMPT + f"```\n{sample}\n```", model="gemma2")
    lvl0_titles.append(outp)

for sample in tqdm.tqdm(top_tokens_lvl1_arr):
    outp = execute_prompt(SUMMARIZING_PROMPT + f"```\n{sample}\n```", model="gemma2")
    lvl1_titles.append(outp)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# Postprocessing

# %%
def postprocess_topic_name(topic_name):
    re_pattern = re.compile(r'"topic_\d+":\s*"([^"]+)"')
    return re.match(re_pattern, topic_name).groups()[0]


lvl0_titles_processed = list(map(postprocess_topic_name, lvl0_titles))
lvl1_titles_processed = list(map(postprocess_topic_name, lvl1_titles))

# %%
with open("llm_output/gemma2/levels.json", "w") as fd:
    default_topic_names_lvl0 = [f"topic_{n}" for n in range(len(lvl0_titles_processed))]
    default_topic_names_lvl1 = [f"topic_{n}" for n in range(len(lvl1_titles_processed))]

    json.dump(
        {
            'level0': dict(zip(default_topic_names_lvl0, lvl0_titles_processed)),
            'level1': dict(zip(default_topic_names_lvl1, lvl1_titles_processed)),
        },
        fd
    )

with open("llm_output/gemma2/levels.json", "r") as fd:
    generated_topics = json.load(fd)

generated_topics
# Out:
# {'level0': {'topic_0': 'Agile разработка в IT компаниях',
#   'topic_1': 'Возможности использования Linux для программирования',
#   'topic_2': 'Использование открытых лицензий в IT',
#   'topic_3': 'Автоматизация тестирования и информационной безопасности',
#   'topic_4': 'Свободное ПО в образовании и информационных системах',
#   'topic_5': 'Дистрибутивы Linux и параллельное программирование',
#   'topic_6': 'Специалисты и дискуссии в сфере IT',
#   'topic_7': 'Управление проектами и продуктами в компании',
#   'topic_8': 'Проектирование мобильных интерфейсов',
#   'topic_9': 'Управление бизнес-процессами и возможности пользователей',
#   'topic_10': 'Управление серверами и базами данных',
#   'topic_11': 'Проектирование устройств и контроллеров',
#   'topic_12': 'Разработка ПО и Big Data: Agile подходы',
#   'topic_13': 'Курсы программирования для студентов',
#   'topic_14': 'Разработка и тестирование ядра систем',
#   'topic_15': 'Архитектура распределённых систем и облачных сервисов',
#   'topic_16': 'Анализ текста и алгоритмы машинного обучения',
#   'topic_17': 'Управление требованиями и качеством',
#   'topic_18': 'Подходы в программировании и моделировании',
#   'topic_19': 'Российские IT-компании и технические проекты'},
#  'level1': {'topic_0': 'Тенденции Open Source и бизнес-модели',
#   'topic_1': 'API-боты и автоматизированная верификация',
#   'topic_2': 'Автоматизация тестирования и повышение качества ПО',
#   'topic_3': 'Kerberos и безопасность домена',
#   'topic_4': 'Обработка данных и базы данных',
#   'topic_5': 'Проекты в области компьютерного зрения',
#   'topic_6': 'Разработка ПО с открытым исходным кодом (GPL)',
#   'topic_7': 'Инженерия управления и решения задач',
#   'topic_8': 'Автоматизация тестирования и CI/CD',
#   'topic_9': 'Принципы и процессы в управлении продуктами',
#   'topic_10': 'Робототехника в высшем образовании',
#   'topic_11': 'Статические механизмы в тестировании',
#   'topic_12': 'Возможности Linux-ядра в разработке схем',
#   'topic_13': 'Спецификации и рамки для параллельного программирования',
#   'topic_14': 'Системы решения задач в образовании',
#   'topic_15': 'Python для выполнения программ на разных платформах',
#   'topic_16': 'Технологии и подходы в развитии бизнеса',
#   'topic_17': 'Альтернативные Linux-дистрибутивы и платформы',
#   'topic_18': 'DevOps и сборка ядра Linux',
#   'topic_19': 'Планирование и разработка собственных проектов',
#   'topic_20': 'Опыт менеджмента и внедрения систем',
#   'topic_21': 'Метрики роста и эвристика в управлении продуктами',
#   'topic_22': 'Разработка мобильных приложений',
#   'topic_23': 'Мониторинг систем и выявление ошибок',
#   'topic_24': 'UX Russia 2011: Расчет и примеры в UX',
#   'topic_25': 'Протоколы передачи данных для Arduino',
#   'topic_26': 'Agile разработка и Big Data',
#   'topic_27': 'Интерфейсы приложений с машинным обучением',
#   'topic_28': 'Жизненный цикл продукта и управление компанией',
#   'topic_29': 'Agile методологии и практика Scrum',
#   'topic_30': 'Разработка собственных компонентов в open source',
#   'topic_31': 'История контейнеризации и развертывания',
#   'topic_32': 'Организация и управление проектами',
#   'topic_33': 'Управление бизнес-процессами с помощью программирования',
#   'topic_34': 'Серверная аутентификация и хранилища данных',
#   'topic_35': 'Разработка крупных проектов и решение проблем',
#   'topic_36': 'Алгоритмы обработки изображений и вычислений',
#   'topic_37': 'Свободное ПО в образовании',
#   'topic_38': 'Документация и ограничения в технических проектах',
#   'topic_39': 'Юридические аспекты распространения ПО',
#   'topic_40': 'Разработка и использование кода в Scala',
#   'topic_41': 'Оценка качества и тестирование производительности',
#   'topic_42': 'Применение Lean и Scrum в проектах',
#   'topic_43': 'Анализ usability устройств и платформ',
#   'topic_44': 'Анализ текста и методы машинного обучения',
#   'topic_45': 'Виртуальные окружения и взаимодействие пользователей',
#   'topic_46': 'Управление требованиями и дизайн продукта',
#   'topic_47': 'Быстрые решения для дизайна и заказчика',
#   'topic_48': 'Распределённые системы и архитектура сервисов',
#   'topic_49': 'Анализ процессов и этапов',
#   'topic_50': 'Управление данными пользователя в подсистемах',
#   'topic_51': 'Конфигурация и тестирование операционных систем',
#   'topic_52': 'Управление потоками данных в open source проектах',
#   'topic_53': 'Платформы для программирования в облаке',
#   'topic_54': 'Простые и оригинальные IT-услуги',
#   'topic_55': 'Разработка и управление проектами в Agile',
#   'topic_56': 'Аппаратные и программные системы: примеры и платформы',
#   'topic_57': 'Моделирование и методы анализа данных',
#   'topic_58': 'Опыт разработки на Ruby и SAP',
#   'topic_59': 'Платформы для мобильного видео',
#   'topic_60': 'Сетевые решения и управление данными',
#   'topic_61': 'Библиотеки и инструменты для open source проектов',
#   'topic_62': 'Исследование UX-дизайна сайтов',
#   'topic_63': 'Управление проектами и мотивация команды',
#   'topic_64': 'Управление рисками и опытом в развитии процессов',
#   'topic_65': 'Автоматизированные роботы для непрерывного тестирования',
#   'topic_66': 'Функциональное программирование и графические интерфейсы',
#   'topic_67': 'Проектирование пользовательских интерфейсов',
#   'topic_68': 'Поддержка и синхронизация файлов в Open Source проектах',
#   'topic_69': 'Модули и блоки в open-source системах',
#   'topic_70': 'Виртуальные машины в государственном управлении',
#   'topic_71': 'Реализация кластеров и сетей',
#   'topic_72': 'Подходы к программированию и обработке данных',
#   'topic_73': 'Инструменты проектирования прототипов с учетом accessibility',
#   'topic_74': 'Продажа собственных продуктов на рынке',
#   'topic_75': 'DevOps и автоматизация развертывания приложений',
#   'topic_76': 'Развитие IT-сообщества в России',
#   'topic_77': 'Хранение данных и тестирование качества',
#   'topic_78': 'Онлайн-обучение и алгоритмические языки',
#   'topic_79': 'Управление доступом и настройкой PostgreSQL',
#   'topic_80': 'Программирование и робототехника в школе',
#   'topic_81': 'Устройства и платформа памяти',
#   'topic_82': 'UX/UI для сложных веб-приложений',
#   'topic_83': 'Управление бизнес-процессами и версиями данных',
#   'topic_84': 'Практическое обучение программированию для студентов',
#   'topic_85': 'Виды информации и возможности ее использования',
#   'topic_86': 'Разработка и внедрение новых продуктов',
#   'topic_87': 'Возможности моделирования и изменения бизнес-процессов',
#   'topic_88': 'Agile-разработка и ретроспективы проектов',
#   'topic_89': 'Agile команды и компании в современном мире',
#   'topic_90': 'Реализация кода и BDD практики',
#   'topic_91': 'Анализ кейсов в управлении продуктами',
#   'topic_92': 'Agile разработка и доклады',
#   'topic_93': 'Обучение и мотивация в HR',
#   'topic_94': 'Сложности миграции UI и технологии',
#   'topic_95': 'Шаблоны и шаблонизация в Linux',
#   'topic_96': 'Дискуссии HR о развитии персонала',
#   'topic_97': 'Возможности и версии Linux',
#   'topic_98': 'Средства защиты от уязвимостей в операционных системах',
#   'topic_99': 'Управление системами с открытым исходным кодом'}}

# %% [markdown]
# ## Few-shot classification with gemma2

# %%
GEMMA_CLASSIFICATION_PROMPT_PREFIX = f"""<system_prompt>
YOU ARE AN EXPERT IN MULTICLASS MULTILABEL HIERARCHICAL TEXT CLASSIFICATION FOR IT-RELATED CONTENT. YOUR TASK IS TO ANALYZE TEXTS FROM IT CONFERENCES (IN RUSSIAN AND ENGLISH) OF VARYING LENGTH (FROM SHORT TITLES TO DETAILED ARTICLES) AND ASSIGN THE MOST RELEVANT HIERARCHICAL CATEGORIES BASED ON PROVIDED LABELS AND THEIR RELATIONSHIPS.

### INSTRUCTIONS ###

1. **READ AND UNDERSTAND THE TEXT**: 
   - IDENTIFY the key topics, themes, and context of the text.
   - DISTINGUISH between the main focus and supplementary details.

2. **USE THE PROVIDED HIERARCHICAL CATEGORY STRUCTURE**:
   - ALWAYS ASSIGN CATEGORIES from the provided list.
   - IF THE TEXT IS SHORT, prioritize HIGH-LEVEL and GENERAL categories.
   - IF THE TEXT IS LONG, assign DETAILED, LOW-LEVEL, and SPECIFIC categories.

3. **MAINTAIN CONSISTENCY**:
   - SELECT categories based on the text content and not assumptions.
   - ENSURE the categories are logically consistent with the hierarchy.

4. **OUTPUT FORMAT**:
   - RETURN ONLY a Python-style list of categories (e.g., `['Category1', 'Category2']`).
   - DO NOT include explanations, reasoning, or logs in the response.

5. **CONSIDER CONTEXTUAL RELEVANCE**:
   - ACCOUNT for both linguistic (Russian/English) and domain-specific terminology.
   - INCLUDE categories related to both technical and thematic aspects of the text.

6. **PRIORITIZATION RULES**:
   - PRIORITIZE categories that capture the technical or thematic core of the text.
   - AVOID unrelated or overly broad categories unless the text explicitly requires them.
   - DO NOT ASSIGN categories without clear support in the text.
   - DO NOT INCLUDE reasoning, analysis, or commentary in the output.

### CHAIN OF THOUGHTS ###

1. **UNDERSTAND THE TEXT**:
   - READ the text carefully to grasp the main idea.
   - IDENTIFY specific keywords and phrases pointing to IT-related topics.

2. **DETERMINE CATEGORY SCOPE**:
   - CLASSIFY short texts with a focus on overarching themes or event types.
   - CLASSIFY long texts with a focus on detailed, specific technical topics.

3. **FILTER CATEGORIES**:
   - USE a subset of categories based on the keywords and context in the text.
   - PRIORITIZE specific and detailed categories for technical texts.

4. **ASSIGN RELEVANT CATEGORIES**:
   - CHOOSE categories with direct support in the text.
   - IF THE TEXT IS AMBIGUOUS OR GENERAL, assign higher-level categories.

5. **VALIDATE SELECTIONS**:
   - CHECK for logical consistency.
   - REMOVE any categories that are redundant or insufficiently supported.

6. **FORMAT THE OUTPUT**:
   - STRUCTURE the list clearly in Python list format.
   - INCLUDE all directly relevant categories.

7. **REVIEW AND FINALIZE**:
   - ENSURE all chosen categories align with the hierarchy and text content.
   - VERIFY the list is complete and free of errors.

### CATEGORIES ###
{list(ALL_CATEGORIES_WITHOUT_NAMES)}

### EXAMPLES ###

#### Input Sample:
3 практики креативного мышления в разработке пользовательских интерфейсов (Владимир Завертайлов, SECR-2013) <sep> В докладе рассмотрены креативные методики «Визуальный бриф», «Метод Уолта Диснея» и «SCAMPER», и применение этих методик для разработки интерфейсов и дизайна программных продуктов (web-систем и мобильных приложений).

#### Output:
['UX проектирование', 'Прототипирование UI']

---

#### Input Sample:
Design of PyTest-based Framework for Modules that Use RabbitMQ and REST (Никита Ковригин, SECR-2017) <sep> How to achieve fast test development process and make it easy for QA engineers to write tests and don’t think about difficulties? How to save our time and resources if test objects are “big” and “complex” using pytest? We have our own experience and want to show you how we solved it.

#### Output:
['Talks in English', 'Автоматизированное тестирование']

---

#### Input Sample:
Применение популярных протоколов и свободного ПО в управлении мобильным роботом (Андрей Дунец, LVEE-2014) <sep> We consider the problems of telemetry, positioning and control of the mobile robot for monitoring of rivers and lakes. The project used Bluetooth technology for the transmission of telemetry data. RTKLIB library implementation of Real-Time Kinematic algorithm used for positioning. The current version of the control system is based on the Ardupilot project.

#### Output:
['Arduino', 'Робототехника']

---

### WHAT NOT TO DO ###

- **DO NOT** ASSIGN CATEGORIES OUTSIDE THE PROVIDED LIST.
- **DO NOT** ASSIGN CATEGORIES WITHOUT CLEAR TEXTUAL SUPPORT.
- **DO NOT** DUPLICATE HIGH-LEVEL AND LOW-LEVEL CATEGORIES IN THE SAME LIST (E.G., 'AGILE' AND 'AGILE-КУЛЬТУРА').
- **DO NOT** FAIL TO ADAPT CATEGORY SELECTION BASED ON TEXT LENGTH AND DETAIL.

### FINAL OUTPUT FORMAT ###

- Python-style list of categories (e.g., `['Category1', 'Category2']`).
- INCLUDE only categories directly relevant to the content.

### USER INPUT ###
- TEXT: 
"""

GEMMA_CLASSIFICATION_PROMPT_SUFFIX = """
### OUTPUT ###
- Python-style list of categories only.

</system_prompt>
"""

# %%
np.random.seed(123)
rand_ids = np.random.choice(len(processed_data), 4, replace=False)
rand_text_samples = [elem['text'] for elem in np.array(processed_data)[rand_ids]]
rand_targets = [elem['categories'] for elem in np.array(processed_data)[rand_ids]]

# %%
for rand_text, rand_trg in zip(rand_text_samples, rand_targets):
    print(rand_text[:100])
    print('Generated target')
    debug_prompt(GEMMA_CLASSIFICATION_PROMPT_PREFIX + "\"" + rand_text[:5000] + "\"" + GEMMA_CLASSIFICATION_PROMPT_SUFFIX, model='gemma2')
    print('True target')
    print(rand_trg)
    print('='*80)
# Out:
# Альтернатива горбатому RPM — двугорбый RPM (Глеб Фотенгауэр-Малиновский, OSSDEVCONF-2016) <sep> Испо
# Generated target
# 2024-12-24 20:12:24,857 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ['Linux', 'Software Development']
#
# True target
# ['Linux-дистрибутивы']
# ================================================================================
# Mine Your Own Business — Using Process Mining to Turn Big Data into Real Value (Wil van der Aalst, S
# Generated target
# 2024-12-24 20:12:26,943 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ```python
# ['Process Mining', 'Business Process Management (BPM)', 'Workflow Management (WfM)', 'Data Mining (DM)', 'Business Intelligence (BI)', 'Machine Learning (ML)', 'Big Data']
# ```
# True target
# ['Моделирование бизнес-процессов']
# ================================================================================
# Дизайн в разработке (Роман Квартальнов, SECR-2015) <sep> Из доклада вы узнаете, как можно сократить
# Generated target
# 2024-12-24 20:12:28,055 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ['Дизайн', 'UX проектирование']
#
# True target
# ['Процесс разработки UX и UI']
# ================================================================================
# Использование системы выделенных признаков для задач поиска по исходному тесту (Алексей Пустыгин, OS
# Generated target
# 2024-12-24 20:12:29,205 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# ```python
# ['method', 'class']
# ```
# True target
# ['Open-source', 'Образование']
# ================================================================================
